# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
rock_path = '/Users/alex/Desktop/DSI-SF-2-akodate/curriculum/week-02/2.4-lab-cleaning-lab/assets/datasets/rock.csv'
rock_df = pd.read_csv(rock_path)

print rock_df.info()
rock_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song Clean      2230 non-null object
# ARTIST CLEAN    2230 non-null object
# Release Year    1653 non-null object
# COMBINED        2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# PlayCount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.4+ KB
# None
#                                        Song Clean   ARTIST CLEAN Release Year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# ...

# %%
def test(input_data):
    print "Input data incoming..."
    print "----------------------"
    print input_data
    
rock_df.head(3).apply(test, axis=0)
rock_df.head(3)
# Out:
# Input data incoming...
# ----------------------
# 0    Caught Up in You
# 1        Fantasy Girl
# 2     Hold On Loosely
# Name: Song Clean, dtype: object
# Input data incoming...
# ----------------------
# 0    .38 Special
# 1    .38 Special
# 2    .38 Special
# Name: ARTIST CLEAN, dtype: object
# Input data incoming...
# ----------------------
# 0    1982
# 1     NaN
# 2    1981
# Name: Release Year, dtype: object
# Input data incoming...
# ----------------------
# 0    Caught Up in You by .38 Special
# 1        Fantasy Girl by .38 Special
# 2     Hold On Loosely by .38 Special
# Name: COMBINED, dtype: object
# Input data incoming...
# ----------------------
# 0    1
# 1    1
# 2    1
# Name: First?, dtype: object
# Input data incoming...
# ----------------------
# 0    1
# 1    0
# 2    1
# Name: Year?, dtype: object
# Input data incoming...
# ----------------------
# 0    82
# 1     3
# 2    85
# Name: PlayCount, dtype: object
# Input data incoming...
# ----------------------
# ...
