# %%
>>> import autosklearn.classification
>>> import sklearn.datasets
>>> digits = sklearn.datasets.load_digits()
>>> X = digits.data
>>> y = digits.target
>>> import numpy as np
>>> indices = np.arange(X.shape[0])
>>> np.random.shuffle(indices)
>>> X = X[indices]
>>> y = y[indices]
>>> X_train = X[:1000]
>>> y_train = y[:1000]
>>> X_test = X[1000:]
>>> y_test = y[1000:]
>>> automl = autosklearn.classification.AutoSklearnClassifier()
>>> automl.fit(X_train, y_train)
>>> print(automl.score(X_test,y_test))
# Out:
# [INFO] [2016-09-10 20:59:22,769:AutoML(1):c78981c2110b7be62d8566d479ad1b7e] Starting to create dummy predictions.
# [INFO] [2016-09-10 20:59:22,795:AutoML(1):c78981c2110b7be62d8566d479ad1b7e] Finished creating dummy prediction 1/2.
# [INFO] [2016-09-10 20:59:22,819:AutoML(1):c78981c2110b7be62d8566d479ad1b7e] Finished creating dummy prediction 2/2.
# [INFO] [2016-09-10 20:59:23,492:AutoML(1):c78981c2110b7be62d8566d479ad1b7e] Start Ensemble with 3599.27sec time left
# [INFO] [2016-09-10 20:59:23,500:AutoML(1):c78981c2110b7be62d8566d479ad1b7e] Start SMAC with 3599.26sec time left
# [ERROR] [2016-09-10 20:59:23,517:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 20:59:23,522:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Training default configurations on a subset of 330/1000 data points.
# [INFO] [2016-09-10 20:59:23,524:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.013847
# 	Members: [0]
# 	Weights: [ 1.]
# 	Identifiers: (1, 2)
# [INFO] [2016-09-10 20:59:23,529:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.013847
# [INFO] [2016-09-10 20:59:23,533:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.017288 seconds
# [INFO] [2016-09-10 20:59:23,536:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many validation set predictions (0)as ensemble predictions (2)!.
# [INFO] [2016-09-10 20:59:23,537:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 3 on SUBSET with size 330 and time limit 180s.
# [INFO] [2016-09-10 20:59:23,538:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many test set predictions (0) as ensemble predictions (2)!
# [INFO] [2016-09-10 20:59:23,538:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'random_forest'
#   classifier:random_forest:bootstrap, Value: 'True'
#   classifier:random_forest:criterion, Value: 'gini'
#   classifier:random_forest:max_depth, Constant: 'None'
#   classifier:random_forest:max_features, Value: 1.0
#   classifier:random_forest:max_leaf_nodes, Constant: 'None'
#   classifier:random_forest:min_samples_leaf, Value: 1
#   classifier:random_forest:min_samples_split, Value: 2
#   classifier:random_forest:min_weight_fraction_leaf, Constant: 0.0
#   classifier:random_forest:n_estimators, Constant: 100
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.01
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'no_preprocessing'
#   rescaling:__choice__, Value: 'min/max'
#
# [INFO] [2016-09-10 20:59:23,891:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 3. configuration on SUBSET. Duration 0.311673; loss 0.084431; status 1; additional run info: ;duration: 0.3116729259490967;num_run:00003
# [INFO] [2016-09-10 20:59:23,893:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished SUBSET training sucessfully with ratio 0.330000
# [INFO] [2016-09-10 20:59:23,898:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 4 on SUBSET with size 330 and time limit 180s.
# [INFO] [2016-09-10 20:59:23,899:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'sgd'
#   classifier:sgd:alpha, Value: 0.0001
#   classifier:sgd:average, Value: 'True'
#   classifier:sgd:eta0, Value: 0.01
#   classifier:sgd:fit_intercept, Constant: 'True'
#   classifier:sgd:learning_rate, Value: 'optimal'
#   classifier:sgd:loss, Value: 'hinge'
#   classifier:sgd:n_iter, Value: 5
#   classifier:sgd:penalty, Value: 'l2'
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.1
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'no_preprocessing'
#   rescaling:__choice__, Value: 'min/max'
#
# [INFO] [2016-09-10 20:59:24,104:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 4. configuration on SUBSET. Duration 0.172501; loss 0.077676; status 1; additional run info: ;duration: 0.1725008487701416;num_run:00004
# [INFO] [2016-09-10 20:59:24,106:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished SUBSET training sucessfully with ratio 0.330000
# [INFO] [2016-09-10 20:59:24,109:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 5 on SUBSET with size 330 and time limit 180s.
# [INFO] [2016-09-10 20:59:24,111:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'extra_trees'
#   classifier:extra_trees:bootstrap, Value: 'False'
#   classifier:extra_trees:criterion, Value: 'gini'
#   classifier:extra_trees:max_depth, Constant: 'None'
#   classifier:extra_trees:max_features, Value: 1.0
#   classifier:extra_trees:min_samples_leaf, Value: 5
#   classifier:extra_trees:min_samples_split, Value: 5
#   classifier:extra_trees:min_weight_fraction_leaf, Constant: 0.0
#   classifier:extra_trees:n_estimators, Constant: 100
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.1
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'select_percentile_classification'
#   preprocessor:select_percentile_classification:percentile, Value: 2.0
#   preprocessor:select_percentile_classification:score_func, Value: 'chi2'
#   rescaling:__choice__, Value: 'min/max'
#
# [INFO] [2016-09-10 20:59:24,527:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 5. configuration on SUBSET. Duration 0.378422; loss 0.695711; status 1; additional run info: ;duration: 0.3784220218658447;num_run:00005
# [INFO] [2016-09-10 20:59:24,529:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished SUBSET training sucessfully with ratio 0.330000
# [INFO] [2016-09-10 20:59:24,532:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 6 on SUBSET with size 330 and time limit 180s.
# [INFO] [2016-09-10 20:59:24,534:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'gaussian_nb'
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.1
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'no_preprocessing'
#   rescaling:__choice__, Value: 'standardize'
#
# [INFO] [2016-09-10 20:59:24,587:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 6. configuration on SUBSET. Duration 0.021537; loss 0.229652; status 1; additional run info: ;duration: 0.021537065505981445;num_run:00006
# [INFO] [2016-09-10 20:59:24,589:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished SUBSET training sucessfully with ratio 0.330000
# [INFO] [2016-09-10 20:59:24,592:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Metadata directory: /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/metalearning/files/acc_metric_multiclass.classification_dense
# [INFO] [2016-09-10 20:59:25,088:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Start calculating metafeatures for c78981c2110b7be62d8566d479ad1b7e
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:1147: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   warnings.warn("Degrees of freedom <= 0 for slice.", RuntimeWarning)
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/numpy/lib/nanfunctions.py:675: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# [INFO] [2016-09-10 20:59:25,106:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Calculating Metafeatures (categorical attributes) took  0.02
# [INFO] [2016-09-10 20:59:25,191:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Calculating Metafeatures (encoded attributes) took  0.07sec
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# [INFO] [2016-09-10 20:59:25,326:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Time left for c78981c2110b7be62d8566d479ad1b7e after finding initial configurations: 3596.43sec
# [INFO] [2016-09-10 20:59:25,330:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Metafeatures for dataset c78981c2110b7be62d8566d479ad1b7euiaeo
#   ClassProbabilityMin: 0.086
#   NumberOfInstancesWithMissingValues: 0.0
#   ClassEntropy: 3.31823327014
#   LogNumberOfInstances: 6.90775527898
#   SymbolsMean: 0
#   LogInverseDatasetRatio: 2.74887219562
#   NumberOfFeaturesWithMissingValues: 0.0
#   SymbolsMax: 0
#   NumberOfCategoricalFeatures: 0
#   InverseDatasetRatio: 15.625
#   LogDatasetRatio: -2.74887219562
#   KurtosisSTD: 227.081032417
#   SkewnessMean: 4.13640603209
#   KurtosisMin: -3.0
#   LandmarkRandomNodeLearner: 0.111081876138
#   RatioNominalToNumerical: 0.0
#   NumberOfMissingValues: 0.0
#   DatasetRatio: 0.064
#   PercentageOfInstancesWithMissingValues: 0.0
#   SkewnessMax: 31.5753226587
#   RatioNumericalToNominal: 0.0
#   NumberOfNumericFeatures: 64
#   LogNumberOfFeatures: 4.15888308336
#   ClassProbabilitySTD: 0.00712741187248
#   SkewnessMin: -1.36951166522
#   PercentageOfFeaturesWithMissingValues: 0.0
#   SymbolsMin: 0
#   NumberOfClasses: 10.0
#   SymbolsSum: 0.0
#   KurtosisMean: 87.3619044662
#   ClassProbabilityMean: 0.1
#   KurtosisMax: 995.001001001
#   NumberOfFeatures: 64.0
#   PercentageOfMissingValues: 0.0
#   SymbolsSTD: 0
#   SkewnessSTD: 8.23584027224
#   NumberOfInstances: 1000.0
#   ClassProbabilityMax: 0.111
#
# [INFO] [2016-09-10 20:59:25,336:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] ['962_acc', '743_acc', '822_acc', '723_acc', '953_acc', '741_acc', '813_acc', '930_acc', '3_acc', '740_acc', '734_acc', '913_acc', '971_acc', '1040_acc', '392_acc', '843_acc', '849_acc', '293_acc', '1130_acc', '184_acc', '1134_acc', '910_acc', '1142_acc', '31_acc', '1020_acc', '980_acc', '1112_acc', '966_acc', '1120_acc', '273_acc', '904_acc', '1018_acc', '751_acc', '44_acc', '845_acc', '718_acc', '1114_acc', '23_acc', '976_acc', '1139_acc', '959_acc', '737_acc', '977_acc', '185_acc', '1021_acc', '722_acc', '46_acc', '923_acc', '837_acc', '846_acc', '1119_acc', '180_acc', '30_acc', '761_acc', '807_acc', '1050_acc', '720_acc', '1036_acc', '554_acc', '881_acc', '823_acc', '1056_acc', '912_acc', '727_acc', '799_acc', '715_acc', '979_acc', '847_acc', '16_acc', '14_acc', '351_acc', '1111_acc', '6_acc', '897_acc', '1049_acc', '995_acc', '958_acc', '797_acc', '978_acc', '752_acc', '18_acc', '772_acc', '816_acc', '60_acc', '396_acc', '1067_acc', '28_acc', '901_acc', '866_acc', '182_acc', '735_acc', '819_acc', '21_acc', '32_acc', '24_acc', '12_acc', '395_acc', '354_acc', '389_acc', '821_acc', '1161_acc', '1053_acc', '1041_acc', '401_acc', '1019_acc', '390_acc', '1068_acc', '1116_acc', '679_acc', '300_acc', '399_acc', '36_acc', '1128_acc', '991_acc', '22_acc', '357_acc', '833_acc', '728_acc', '934_acc', '903_acc', '391_acc', '1002_acc', '38_acc', '393_acc', '1138_acc', '1146_acc', '1069_acc', '1166_acc', '57_acc', '993_acc', '1000_acc', 'c78981c2110b7be62d8566d479ad1b7euiaeo', '398_acc', '179_acc', '806_acc', '181_acc', '917_acc', '803_acc', '914_acc', '871_acc', '26_acc']
# [ERROR] [2016-09-10 20:59:25,545:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 20:59:25,750:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.922324 1: 0.922324 2: 0.922324 3: 0.922324 4: 0.925701 5: 0.925701 6: 0.929078 7: 0.929078 8: 0.929078 9: 0.929078 10: 0.929078 11: 0.932455 12: 0.932455 13: 0.932455 14: 0.932455 15: 0.929078 16: 0.929078 17: 0.929078 18: 0.929078 19: 0.929078 20: 0.929078 21: 0.929078 22: 0.932455 23: 0.932455 24: 0.932455 25: 0.935832 26: 0.935832 27: 0.935832 28: 0.935832 29: 0.935832 30: 0.935832 31: 0.935832 32: 0.935832 33: 0.935832 34: 0.932455 35: 0.932455 36: 0.932455 37: 0.935832 38: 0.935832 39: 0.935832 40: 0.935832 41: 0.935832 42: 0.935832 43: 0.935832 44: 0.935832 45: 0.935832 46: 0.935832 47: 0.935832 48: 0.935832 49: 0.935832
# 	Members: [2, 1, 0, 1, 1, 1, 1, 1, 2, 1, 1, 1, 1, 1, 3, 0, 1, 1, 3, 1, 1, 1, 3, 1, 1, 3, 0, 1, 1, 3, 1, 1, 3, 1, 0, 2, 1, 3, 0, 1, 1, 1, 1, 1, 1, 1, 1, 3, 1, 1]
# 	Weights: [ 0.1   0.68  0.06  0.16  0.  ]
# 	Identifiers: (1, 2) (1, 3) (1, 4) (1, 5)
# [INFO] [2016-09-10 20:59:25,755:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.935832
# [INFO] [2016-09-10 20:59:25,756:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.212384 seconds
# [INFO] [2016-09-10 20:59:25,761:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many validation set predictions (0)as ensemble predictions (6)!.
# [INFO] [2016-09-10 20:59:25,763:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many test set predictions (0) as ensemble predictions (6)!
# [INFO] [2016-09-10 20:59:34,019:scenario] Output to /tmp/autosklearn_tmp_20837_8258
# [INFO] [2016-09-10 21:00:05,923:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 7. configuration (default configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:05,925:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'random_forest'
#   classifier:random_forest:bootstrap, Value: 'True'
#   classifier:random_forest:criterion, Value: 'gini'
#   classifier:random_forest:max_depth, Constant: 'None'
#   classifier:random_forest:max_features, Value: 1.0
#   classifier:random_forest:max_leaf_nodes, Constant: 'None'
#   classifier:random_forest:min_samples_leaf, Value: 1
#   classifier:random_forest:min_samples_split, Value: 2
#   classifier:random_forest:min_weight_fraction_leaf, Constant: 0.0
#   classifier:random_forest:n_estimators, Constant: 100
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.01
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'no_preprocessing'
#   rescaling:__choice__, Value: 'min/max'
#
# [INFO] [2016-09-10 21:00:06,225:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 7. configuration. Duration 0.256580; loss 0.057413; status 1; additional run info: ;duration: 0.2565798759460449;num_run:00007
# [INFO] [2016-09-10 21:00:06,227:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 8. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:06,229:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'libsvm_svc'
#   classifier:libsvm_svc:C, Value: 2.820950683561126
#   classifier:libsvm_svc:coef0, Value: 0.7525658406326312
#   classifier:libsvm_svc:degree, Value: 5
#   classifier:libsvm_svc:gamma, Value: 1.924396413436426
#   classifier:libsvm_svc:kernel, Value: 'poly'
#   classifier:libsvm_svc:max_iter, Constant: -1
#   classifier:libsvm_svc:shrinking, Value: 'True'
#   classifier:libsvm_svc:tol, Value: 0.00037682073690554086
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'select_percentile_classification'
#   preprocessor:select_percentile_classification:percentile, Value: 83.60106850579331
#   preprocessor:select_percentile_classification:score_func, Value: 'f_classif'
#   rescaling:__choice__, Value: 'min/max'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [ 0 16 24 32 39] are constant.
#   UserWarning)
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/pynisher/limit_function_call.py", line 83, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/evaluation/holdout_evaluator.py", line 148, in eval_holdout
#     loss, opt_pred, valid_pred, test_pred = evaluator.fit_predict_and_loss()
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/evaluation/holdout_evaluator.py", line 59, in fit_predict_and_loss
#     self.model.fit(X_train, Y_train)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/base.py", line 63, in fit
#     self.fit_estimator(X, y, **fit_params)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/base.py", line 138, in fit_estimator
#     self.pipeline_.steps[-1][-1].fit(X, y, **fit_params)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/components/classification/libsvm_svc.py", line 122, in fit
#     self.estimator.fit(X, Y)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/svm/base.py", line 193, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/svm/base.py", line 251, in _dense_fit
#     max_iter=self.max_iter, random_seed=random_seed)
#   File "sklearn/svm/libsvm.pyx", line 187, in sklearn.svm.libsvm.fit (sklearn/svm/libsvm.c:2098)
# ValueError: cache_size <= 0
# [INFO] [2016-09-10 21:00:07,321:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 8. configuration. Duration 1.087421; loss 2.000000; status 3; additional run info:
# [INFO] [2016-09-10 21:00:07,325:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 9. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:07,327:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'adaboost'
#   classifier:adaboost:algorithm, Value: 'SAMME'
#   classifier:adaboost:learning_rate, Value: 1.2306208006800998
#   classifier:adaboost:max_depth, Value: 6
#   classifier:adaboost:n_estimators, Value: 499
#   imputation:strategy, Value: 'median'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'extra_trees_preproc_for_classification'
#   preprocessor:extra_trees_preproc_for_classification:bootstrap, Value: 'True'
#   preprocessor:extra_trees_preproc_for_classification:criterion, Value: 'entropy'
#   preprocessor:extra_trees_preproc_for_classification:max_depth, Constant: 'None'
#   preprocessor:extra_trees_preproc_for_classification:max_features, Value: 3.5347851525007146
#   preprocessor:extra_trees_preproc_for_classification:min_samples_leaf, Value: 6
#   preprocessor:extra_trees_preproc_for_classification:min_samples_split, Value: 8
#   preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf, Constant: 0.0
#   preprocessor:extra_trees_preproc_for_classification:n_estimators, Constant: 100
#   rescaling:__choice__, Value: 'standardize'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# [ERROR] [2016-09-10 21:00:07,821:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:08,030:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.942587 1: 0.942587 2: 0.945964 3: 0.949341 4: 0.949341 5: 0.949341 6: 0.949341 7: 0.949341 8: 0.949341 9: 0.949341 10: 0.949341 11: 0.949341 12: 0.949341 13: 0.949341 14: 0.949341 15: 0.949341 16: 0.949341 17: 0.949341 18: 0.949341 19: 0.949341 20: 0.949341 21: 0.949341 22: 0.949341 23: 0.949341 24: 0.949341 25: 0.949341 26: 0.949341 27: 0.949341 28: 0.949341 29: 0.949341 30: 0.949341 31: 0.949341 32: 0.949341 33: 0.949341 34: 0.949341 35: 0.949341 36: 0.949341 37: 0.949341 38: 0.949341 39: 0.949341 40: 0.949341 41: 0.949341 42: 0.949341 43: 0.949341 44: 0.949341 45: 0.949341 46: 0.949341 47: 0.949341 48: 0.949341 49: 0.949341
# 	Members: [5, 5, 3, 5, 5, 5, 5, 3, 5, 5, 3, 1, 5, 5, 3, 5, 5, 5, 3, 1, 5, 5, 3, 5, 5, 3, 1, 0, 5, 5, 3, 5, 5, 5, 3, 1, 5, 5, 3, 5, 5, 3, 1, 5, 5, 3, 5, 5, 5, 3]
# 	Weights: [ 0.02  0.1   0.    0.26  0.    0.62]
# 	Identifiers: (1, 2) (1, 3) (1, 5) (1, 7)
# [INFO] [2016-09-10 21:00:08,034:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.949341
# [INFO] [2016-09-10 21:00:08,036:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.216167 seconds
# [INFO] [2016-09-10 21:00:08,039:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many validation set predictions (0)as ensemble predictions (7)!.
# [INFO] [2016-09-10 21:00:08,042:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many test set predictions (0) as ensemble predictions (7)!
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# [INFO] [2016-09-10 21:00:09,635:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 9. configuration. Duration 2.227205; loss 0.064168; status 1; additional run info: ;duration: 2.2272050380706787;num_run:00009
# [INFO] [2016-09-10 21:00:09,638:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 10. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:09,639:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'liblinear_svc'
#   classifier:liblinear_svc:C, Value: 0.5815868776595028
#   classifier:liblinear_svc:dual, Constant: 'False'
#   classifier:liblinear_svc:fit_intercept, Constant: 'True'
#   classifier:liblinear_svc:intercept_scaling, Constant: 1
#   classifier:liblinear_svc:loss, Value: 'squared_hinge'
#   classifier:liblinear_svc:multi_class, Constant: 'ovr'
#   classifier:liblinear_svc:penalty, Value: 'l2'
#   classifier:liblinear_svc:tol, Value: 0.05261321190581748
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'polynomial'
#   preprocessor:polynomial:degree, Value: 2
#   preprocessor:polynomial:include_bias, Value: 'True'
#   preprocessor:polynomial:interaction_only, Value: 'False'
#   rescaling:__choice__, Value: 'none'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# [INFO] [2016-09-10 21:00:10,010:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 10. configuration. Duration 0.338849; loss 0.033772; status 1; additional run info: ;duration: 0.3388490676879883;num_run:00010
# [INFO] [2016-09-10 21:00:10,012:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 11. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:10,014:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'sgd'
#   classifier:sgd:alpha, Value: 0.0002011208878338422
#   classifier:sgd:average, Value: 'False'
#   classifier:sgd:eta0, Value: 0.0812309539678548
#   classifier:sgd:fit_intercept, Constant: 'True'
#   classifier:sgd:l1_ratio, Value: 0.49756924007684844
#   classifier:sgd:learning_rate, Value: 'invscaling'
#   classifier:sgd:loss, Value: 'hinge'
#   classifier:sgd:n_iter, Value: 554
#   classifier:sgd:penalty, Value: 'elasticnet'
#   classifier:sgd:power_t, Value: 0.2567923580475304
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:minimum_fraction, Value: 0.0007915092939712602
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'nystroem_sampler'
#   preprocessor:nystroem_sampler:coef0, Value: -0.6384046151685252
#   preprocessor:nystroem_sampler:degree, Value: 3
#   preprocessor:nystroem_sampler:gamma, Value: 0.22795987796995726
#   preprocessor:nystroem_sampler:kernel, Value: 'poly'
#   preprocessor:nystroem_sampler:n_components, Value: 3207
#   rescaling:__choice__, Value: 'none'
#
# [ERROR] [2016-09-10 21:00:10,049:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/kernel_approximation.py:463: UserWarning: n_components > n_samples. This is not possible.
# n_components was set to n_samples, which results in inefficient evaluation of the full kernel.
#   warnings.warn("n_components > n_samples. This is not possible.\n"
# [INFO] [2016-09-10 21:00:10,385:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.966228 1: 0.966228 2: 0.966228 3: 0.966228 4: 0.966228 5: 0.966228 6: 0.966228 7: 0.966228 8: 0.966228 9: 0.966228 10: 0.966228 11: 0.966228 12: 0.966228 13: 0.966228 14: 0.966228 15: 0.966228 16: 0.966228 17: 0.966228 18: 0.966228 19: 0.966228 20: 0.966228 21: 0.966228 22: 0.966228 23: 0.966228 24: 0.966228 25: 0.966228 26: 0.966228 27: 0.966228 28: 0.966228 29: 0.966228 30: 0.966228 31: 0.966228 32: 0.966228 33: 0.966228 34: 0.966228 35: 0.966228 36: 0.966228 37: 0.966228 38: 0.966228 39: 0.966228 40: 0.966228 41: 0.966228 42: 0.966228 43: 0.966228 44: 0.966228 45: 0.966228 46: 0.966228 47: 0.966228 48: 0.966228 49: 0.966228
# 	Members: [7, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.98  0.02]
# 	Identifiers: (1, 9) (1, 10)
# [INFO] [2016-09-10 21:00:10,390:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.966228
# [INFO] [2016-09-10 21:00:10,392:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.343440 seconds
# [INFO] [2016-09-10 21:00:10,394:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many validation set predictions (0)as ensemble predictions (9)!.
# [INFO] [2016-09-10 21:00:10,396:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many test set predictions (0) as ensemble predictions (9)!
# [INFO] [2016-09-10 21:00:27,231:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 11. configuration. Duration 17.176974; loss 0.050659; status 1; additional run info: ;duration: 17.176973819732666;num_run:00011
# [INFO] [2016-09-10 21:00:27,234:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 12. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:27,235:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'proj_logit'
#   classifier:proj_logit:max_epochs, Value: 2
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.0011870322904213703
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'no_preprocessing'
#   rescaling:__choice__, Value: 'none'
#
# [INFO] [2016-09-10 21:00:27,312:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 12. configuration. Duration 0.046132; loss 0.067545; status 1; additional run info: ;duration: 0.04613208770751953;num_run:00012
# [INFO] [2016-09-10 21:00:27,314:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 13. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:27,316:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'lda'
#   classifier:lda:n_components, Value: 242
#   classifier:lda:shrinkage, Value: 'None'
#   classifier:lda:tol, Value: 0.0011339574479631279
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:minimum_fraction, Value: 0.004889144803037605
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'gem'
#   preprocessor:gem:N, Value: 8
#   preprocessor:gem:precond, Value: 0.39344596751061517
#   rescaling:__choice__, Value: 'min/max'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/discriminant_analysis.py:453: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# [INFO] [2016-09-10 21:00:27,989:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 13. configuration. Duration 0.627736; loss 0.229652; status 1; additional run info: ;duration: 0.6277360916137695;num_run:00013
# [INFO] [2016-09-10 21:00:27,992:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 14. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:27,994:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'adaboost'
#   classifier:adaboost:algorithm, Value: 'SAMME'
#   classifier:adaboost:learning_rate, Value: 1.0081104516473922
#   classifier:adaboost:max_depth, Value: 6
#   classifier:adaboost:n_estimators, Value: 468
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'liblinear_svc_preprocessor'
#   preprocessor:liblinear_svc_preprocessor:C, Value: 1.1828431725901418
#   preprocessor:liblinear_svc_preprocessor:dual, Constant: 'False'
#   preprocessor:liblinear_svc_preprocessor:fit_intercept, Constant: 'True'
#   preprocessor:liblinear_svc_preprocessor:intercept_scaling, Constant: 1
#   preprocessor:liblinear_svc_preprocessor:loss, Value: 'squared_hinge'
#   preprocessor:liblinear_svc_preprocessor:multi_class, Constant: 'ovr'
#   preprocessor:liblinear_svc_preprocessor:penalty, Constant: 'l1'
#   preprocessor:liblinear_svc_preprocessor:tol, Value: 0.0022792606924326923
#   rescaling:__choice__, Value: 'min/max'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# [ERROR] [2016-09-10 21:00:28,425:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:29,135:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.966228 1: 0.966228 2: 0.966228 3: 0.966228 4: 0.966228 5: 0.966228 6: 0.966228 7: 0.966228 8: 0.966228 9: 0.966228 10: 0.966228 11: 0.966228 12: 0.966228 13: 0.966228 14: 0.966228 15: 0.966228 16: 0.966228 17: 0.966228 18: 0.966228 19: 0.966228 20: 0.966228 21: 0.966228 22: 0.966228 23: 0.966228 24: 0.966228 25: 0.966228 26: 0.966228 27: 0.966228 28: 0.966228 29: 0.966228 30: 0.966228 31: 0.966228 32: 0.966228 33: 0.966228 34: 0.966228 35: 0.966228 36: 0.966228 37: 0.966228 38: 0.966228 39: 0.966228 40: 0.966228 41: 0.966228 42: 0.966228 43: 0.966228 44: 0.966228 45: 0.966228 46: 0.966228 47: 0.966228 48: 0.966228 49: 0.966228
# 	Members: [7, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.98  0.02  0.    0.    0.  ]
# 	Identifiers: (1, 9) (1, 10)
# [INFO] [2016-09-10 21:00:29,148:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.966228
# [INFO] [2016-09-10 21:00:29,151:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.727473 seconds
# [INFO] [2016-09-10 21:00:29,153:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble output did not change.
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function transform is deprecated; Support to use estimators as feature selectors will be removed in version 0.19. Use SelectFromModel instead.
#   warnings.warn(msg, category=DeprecationWarning)
# [INFO] [2016-09-10 21:00:31,815:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 14. configuration. Duration 3.753265; loss 0.043904; status 1; additional run info: ;duration: 3.753265142440796;num_run:00014
# [INFO] [2016-09-10 21:00:31,818:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 15. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:31,820:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'libsvm_svc'
#   classifier:libsvm_svc:C, Value: 2099.097215335698
#   classifier:libsvm_svc:coef0, Value: 0.32850098053260424
#   classifier:libsvm_svc:degree, Value: 3
#   classifier:libsvm_svc:gamma, Value: 2.809557625370355
#   classifier:libsvm_svc:kernel, Value: 'poly'
#   classifier:libsvm_svc:max_iter, Constant: -1
#   classifier:libsvm_svc:shrinking, Value: 'False'
#   classifier:libsvm_svc:tol, Value: 0.003213729117706896
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:minimum_fraction, Value: 0.0033839910940432396
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'select_rates'
#   preprocessor:select_rates:alpha, Value: 0.08594367101091721
#   preprocessor:select_rates:mode, Value: 'fpr'
#   preprocessor:select_rates:score_func, Value: 'chi2'
#   rescaling:__choice__, Value: 'min/max'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/pynisher/limit_function_call.py", line 83, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/evaluation/holdout_evaluator.py", line 148, in eval_holdout
#     loss, opt_pred, valid_pred, test_pred = evaluator.fit_predict_and_loss()
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/evaluation/holdout_evaluator.py", line 59, in fit_predict_and_loss
#     self.model.fit(X_train, Y_train)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/base.py", line 63, in fit
#     self.fit_estimator(X, y, **fit_params)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/base.py", line 138, in fit_estimator
#     self.pipeline_.steps[-1][-1].fit(X, y, **fit_params)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/components/classification/libsvm_svc.py", line 122, in fit
#     self.estimator.fit(X, Y)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/svm/base.py", line 193, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/svm/base.py", line 251, in _dense_fit
#     max_iter=self.max_iter, random_seed=random_seed)
#   File "sklearn/svm/libsvm.pyx", line 187, in sklearn.svm.libsvm.fit (sklearn/svm/libsvm.c:2098)
# ValueError: cache_size <= 0
# [INFO] [2016-09-10 21:00:32,962:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 15. configuration. Duration 1.136040; loss 2.000000; status 3; additional run info:
# [INFO] [2016-09-10 21:00:32,964:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 16. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:32,966:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'liblinear_svc'
#   classifier:liblinear_svc:C, Value: 62.21750028494345
#   classifier:liblinear_svc:dual, Constant: 'False'
#   classifier:liblinear_svc:fit_intercept, Constant: 'True'
#   classifier:liblinear_svc:intercept_scaling, Constant: 1
#   classifier:liblinear_svc:loss, Value: 'squared_hinge'
#   classifier:liblinear_svc:multi_class, Constant: 'ovr'
#   classifier:liblinear_svc:penalty, Value: 'l2'
#   classifier:liblinear_svc:tol, Value: 0.0002178180133457927
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:minimum_fraction, Value: 0.028777961041830738
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'polynomial'
#   preprocessor:polynomial:degree, Value: 3
#   preprocessor:polynomial:include_bias, Value: 'False'
#   preprocessor:polynomial:interaction_only, Value: 'False'
#   rescaling:__choice__, Value: 'none'
# You are already timing task: index_run4
# [ERROR] [2016-09-10 21:00:33,163:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:33,536:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.966228 1: 0.966228 2: 0.966228 3: 0.966228 4: 0.966228 5: 0.966228 6: 0.966228 7: 0.966228 8: 0.966228 9: 0.966228 10: 0.966228 11: 0.966228 12: 0.966228 13: 0.966228 14: 0.966228 15: 0.966228 16: 0.966228 17: 0.966228 18: 0.966228 19: 0.966228 20: 0.966228 21: 0.966228 22: 0.966228 23: 0.966228 24: 0.966228 25: 0.966228 26: 0.966228 27: 0.966228 28: 0.966228 29: 0.966228 30: 0.966228 31: 0.966228 32: 0.966228 33: 0.966228 34: 0.966228 35: 0.966228 36: 0.966228 37: 0.966228 38: 0.966228 39: 0.966228 40: 0.966228 41: 0.966228 42: 0.966228 43: 0.966228 44: 0.966228 45: 0.966228 46: 0.966228 47: 0.966228 48: 0.966228 49: 0.966228
# 	Members: [7, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.98  0.02  0.    0.    0.    0.  ]
# 	Identifiers: (1, 9) (1, 10)
# [INFO] [2016-09-10 21:00:33,541:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.966228
# [INFO] [2016-09-10 21:00:33,543:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.380570 seconds
# [INFO] [2016-09-10 21:00:33,544:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble output did not change.
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# [INFO] [2016-09-10 21:00:37,629:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 16. configuration. Duration 4.612182; loss 0.033772; status 1; additional run info: ;duration: 4.612181901931763;num_run:00016
# [INFO] [2016-09-10 21:00:37,631:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 17. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:37,633:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'extra_trees'
#   classifier:extra_trees:bootstrap, Value: 'True'
#   classifier:extra_trees:criterion, Value: 'gini'
#   classifier:extra_trees:max_depth, Constant: 'None'
#   classifier:extra_trees:max_features, Value: 2.3779010566365115
#   classifier:extra_trees:min_samples_leaf, Value: 2
#   classifier:extra_trees:min_samples_split, Value: 4
#   classifier:extra_trees:min_weight_fraction_leaf, Constant: 0.0
#   classifier:extra_trees:n_estimators, Constant: 100
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:minimum_fraction, Value: 0.004305770290473698
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'select_rates'
#   preprocessor:select_rates:alpha, Value: 0.30934089491790895
#   preprocessor:select_rates:mode, Value: 'fdr'
#   preprocessor:select_rates:score_func, Value: 'f_classif'
#   rescaling:__choice__, Value: 'none'
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [ 0 16 24 32 39] are constant.
#   UserWarning)
# [INFO] [2016-09-10 21:00:37,961:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 17. configuration. Duration 0.287382; loss 0.057413; status 1; additional run info: ;duration: 0.2873818874359131;num_run:00017
# [INFO] [2016-09-10 21:00:37,964:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 18. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:37,965:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'proj_logit'
#   classifier:proj_logit:max_epochs, Value: 11
#   imputation:strategy, Value: 'median'
#   one_hot_encoding:minimum_fraction, Value: 0.002883367159521145
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'gem'
#   preprocessor:gem:N, Value: 16
#   preprocessor:gem:precond, Value: 0.30628439346357783
#   rescaling:__choice__, Value: 'standardize'
#
# [INFO] [2016-09-10 21:00:39,518:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 18. configuration. Duration 1.508772; loss 0.023641; status 1; additional run info: ;duration: 1.5087721347808838;num_run:00018
# [INFO] [2016-09-10 21:00:39,520:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 19. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:39,522:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'none'
#   classifier:__choice__, Value: 'sgd'
#   classifier:sgd:alpha, Value: 0.00039961166337423236
#   classifier:sgd:average, Value: 'False'
#   classifier:sgd:epsilon, Value: 0.0017527970920483906
#   classifier:sgd:eta0, Value: 0.060041614581907
#   classifier:sgd:fit_intercept, Constant: 'True'
#   classifier:sgd:l1_ratio, Value: 0.36339240847373755
#   classifier:sgd:learning_rate, Value: 'optimal'
#   classifier:sgd:loss, Value: 'modified_huber'
#   classifier:sgd:n_iter, Value: 939
#   classifier:sgd:penalty, Value: 'elasticnet'
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'select_percentile_classification'
#   preprocessor:select_percentile_classification:percentile, Value: 76.84823099284878
#   preprocessor:select_percentile_classification:score_func, Value: 'chi2'
#   rescaling:__choice__, Value: 'normalize'
# You are already timing task: index_run4
# [ERROR] [2016-09-10 21:00:39,558:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:40,192:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.976359 1: 0.976359 2: 0.976359 3: 0.976359 4: 0.976359 5: 0.976359 6: 0.976359 7: 0.976359 8: 0.976359 9: 0.976359 10: 0.976359 11: 0.976359 12: 0.976359 13: 0.976359 14: 0.976359 15: 0.976359 16: 0.976359 17: 0.976359 18: 0.976359 19: 0.976359 20: 0.976359 21: 0.976359 22: 0.976359 23: 0.976359 24: 0.979737 25: 0.979737 26: 0.979737 27: 0.979737 28: 0.979737 29: 0.979737 30: 0.979737 31: 0.979737 32: 0.979737 33: 0.976359 34: 0.976359 35: 0.976359 36: 0.976359 37: 0.976359 38: 0.976359 39: 0.976359 40: 0.976359 41: 0.976359 42: 0.976359 43: 0.976359 44: 0.976359 45: 0.976359 46: 0.976359 47: 0.976359 48: 0.976359 49: 0.976359
# 	Members: [14, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 11, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.96  0.    0.    0.    0.    0.02
#   0.    0.    0.02]
# 	Identifiers: (1, 9) (1, 14) (1, 18)
# [INFO] [2016-09-10 21:00:40,197:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.976359
# [INFO] [2016-09-10 21:00:40,199:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.642259 seconds
# [INFO] [2016-09-10 21:00:40,201:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many validation set predictions (0)as ensemble predictions (16)!.
# [INFO] [2016-09-10 21:00:40,203:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Could not find as many test set predictions (0) as ensemble predictions (16)!
# [INFO] [2016-09-10 21:00:43,322:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 19. configuration. Duration 3.768012; loss 0.077676; status 1; additional run info: ;duration: 3.768012046813965;num_run:00019
# [INFO] [2016-09-10 21:00:43,325:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 20. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:43,326:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'libsvm_svc'
#   classifier:libsvm_svc:C, Value: 295.4185183083245
#   classifier:libsvm_svc:gamma, Value: 0.05098015552849704
#   classifier:libsvm_svc:kernel, Value: 'rbf'
#   classifier:libsvm_svc:max_iter, Constant: -1
#   classifier:libsvm_svc:shrinking, Value: 'False'
#   classifier:libsvm_svc:tol, Value: 0.01616175671031427
#   imputation:strategy, Value: 'median'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'feature_agglomeration'
#   preprocessor:feature_agglomeration:affinity, Value: 'cosine'
#   preprocessor:feature_agglomeration:linkage, Value: 'complete'
# ...
#   UserWarning)
# You are already timing task: index_run5
# [ERROR] [2016-09-10 21:00:46,790:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:47,382:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.976359 1: 0.976359 2: 0.976359 3: 0.976359 4: 0.976359 5: 0.976359 6: 0.976359 7: 0.976359 8: 0.976359 9: 0.976359 10: 0.976359 11: 0.976359 12: 0.976359 13: 0.976359 14: 0.976359 15: 0.976359 16: 0.976359 17: 0.976359 18: 0.976359 19: 0.976359 20: 0.976359 21: 0.976359 22: 0.976359 23: 0.976359 24: 0.979737 25: 0.979737 26: 0.979737 27: 0.979737 28: 0.979737 29: 0.979737 30: 0.979737 31: 0.979737 32: 0.979737 33: 0.976359 34: 0.976359 35: 0.976359 36: 0.976359 37: 0.976359 38: 0.976359 39: 0.976359 40: 0.976359 41: 0.976359 42: 0.976359 43: 0.976359 44: 0.976359 45: 0.976359 46: 0.976359 47: 0.976359 48: 0.976359 49: 0.976359
# 	Members: [14, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 11, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.96  0.    0.    0.    0.    0.02
#   0.    0.    0.02  0.    0.    0.  ]
# 	Identifiers: (1, 9) (1, 14) (1, 18)
# [INFO] [2016-09-10 21:00:47,387:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.976359
# [INFO] [2016-09-10 21:00:47,388:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.599430 seconds
# [INFO] [2016-09-10 21:00:47,390:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble output did not change.
# [INFO] [2016-09-10 21:00:50,313:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 23. configuration. Duration 4.776368; loss 0.064168; status 1; additional run info: ;duration: 4.776367902755737;num_run:00023
# [INFO] [2016-09-10 21:00:50,315:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 24. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:50,317:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'sgd'
#   classifier:sgd:alpha, Value: 0.0005401543374603144
#   classifier:sgd:average, Value: 'False'
#   classifier:sgd:eta0, Value: 0.04377140004056303
#   classifier:sgd:fit_intercept, Constant: 'True'
#   classifier:sgd:learning_rate, Value: 'optimal'
#   classifier:sgd:loss, Value: 'log'
#   classifier:sgd:n_iter, Value: 943
#   classifier:sgd:penalty, Value: 'l2'
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:minimum_fraction, Value: 0.0007887810786977907
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'select_rates'
#   preprocessor:select_rates:alpha, Value: 0.17377268248209546
#   preprocessor:select_rates:mode, Value: 'fwe'
#   preprocessor:select_rates:score_func, Value: 'chi2'
#   rescaling:__choice__, Value: 'min/max'
# You are already timing task: index_run5
# [ERROR] [2016-09-10 21:00:51,400:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:52,028:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.976359 1: 0.976359 2: 0.976359 3: 0.976359 4: 0.976359 5: 0.976359 6: 0.976359 7: 0.976359 8: 0.976359 9: 0.976359 10: 0.976359 11: 0.976359 12: 0.976359 13: 0.976359 14: 0.976359 15: 0.976359 16: 0.976359 17: 0.976359 18: 0.976359 19: 0.976359 20: 0.976359 21: 0.976359 22: 0.976359 23: 0.976359 24: 0.979737 25: 0.979737 26: 0.979737 27: 0.979737 28: 0.979737 29: 0.979737 30: 0.979737 31: 0.979737 32: 0.979737 33: 0.976359 34: 0.976359 35: 0.976359 36: 0.976359 37: 0.976359 38: 0.976359 39: 0.976359 40: 0.976359 41: 0.976359 42: 0.976359 43: 0.976359 44: 0.976359 45: 0.976359 46: 0.976359 47: 0.976359 48: 0.976359 49: 0.976359
# 	Members: [14, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 11, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.96  0.    0.    0.    0.    0.02
#   0.    0.    0.02  0.    0.    0.    0.  ]
# 	Identifiers: (1, 9) (1, 14) (1, 18)
# [INFO] [2016-09-10 21:00:52,033:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.976359
# [INFO] [2016-09-10 21:00:52,035:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.635611 seconds
# [INFO] [2016-09-10 21:00:52,037:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble output did not change.
# [INFO] [2016-09-10 21:00:52,966:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 24. configuration. Duration 2.617982; loss 0.077676; status 1; additional run info: ;duration: 2.6179819107055664;num_run:00024
# [INFO] [2016-09-10 21:00:52,969:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 25. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:00:52,970:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'passive_aggressive'
#   classifier:passive_aggressive:C, Value: 0.0036975653885940544
#   classifier:passive_aggressive:fit_intercept, Constant: 'True'
#   classifier:passive_aggressive:loss, Value: 'hinge'
#   classifier:passive_aggressive:n_iter, Value: 326
#   imputation:strategy, Value: 'mean'
#   one_hot_encoding:use_minimum_fraction, Value: 'False'
#   preprocessor:__choice__, Value: 'kitchen_sinks'
#   preprocessor:kitchen_sinks:gamma, Value: 0.6227804363658538
#   preprocessor:kitchen_sinks:n_components, Value: 1821
#   rescaling:__choice__, Value: 'normalize'
# You are already timing task: index_run5
# [ERROR] [2016-09-10 21:00:54,042:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:00:54,693:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.976359 1: 0.976359 2: 0.976359 3: 0.976359 4: 0.976359 5: 0.976359 6: 0.976359 7: 0.976359 8: 0.976359 9: 0.976359 10: 0.976359 11: 0.976359 12: 0.976359 13: 0.976359 14: 0.976359 15: 0.976359 16: 0.976359 17: 0.976359 18: 0.976359 19: 0.976359 20: 0.976359 21: 0.976359 22: 0.976359 23: 0.976359 24: 0.979737 25: 0.979737 26: 0.979737 27: 0.979737 28: 0.979737 29: 0.979737 30: 0.979737 31: 0.979737 32: 0.979737 33: 0.976359 34: 0.976359 35: 0.976359 36: 0.976359 37: 0.976359 38: 0.976359 39: 0.976359 40: 0.976359 41: 0.976359 42: 0.976359 43: 0.976359 44: 0.976359 45: 0.976359 46: 0.976359 47: 0.976359 48: 0.976359 49: 0.976359
# 	Members: [14, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 11, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.96  0.    0.    0.    0.    0.02
#   0.    0.    0.02  0.    0.    0.    0.    0.  ]
# 	Identifiers: (1, 9) (1, 14) (1, 18)
# [INFO] [2016-09-10 21:00:54,697:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.976359
# [INFO] [2016-09-10 21:00:54,699:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.657287 seconds
# [INFO] [2016-09-10 21:00:54,700:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble output did not change.
# [INFO] [2016-09-10 21:01:02,842:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Finished evaluating 25. configuration. Duration 9.838653; loss 0.077676; status 1; additional run info: ;duration: 9.838653087615967;num_run:00025
# [INFO] [2016-09-10 21:01:02,845:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Starting to evaluate 26. configuration (meta-learning configuration) with time limit 360s.
# [INFO] [2016-09-10 21:01:02,846:AutoMLSMBO(1)::c78981c2110b7be62d8566d479ad1b7e] Configuration:
#   balancing:strategy, Value: 'weighting'
#   classifier:__choice__, Value: 'adaboost'
#   classifier:adaboost:algorithm, Value: 'SAMME'
#   classifier:adaboost:learning_rate, Value: 0.08921861937738111
#   classifier:adaboost:max_depth, Value: 8
#   classifier:adaboost:n_estimators, Value: 473
#   imputation:strategy, Value: 'most_frequent'
#   one_hot_encoding:minimum_fraction, Value: 0.46025920786341173
#   one_hot_encoding:use_minimum_fraction, Value: 'True'
#   preprocessor:__choice__, Value: 'polynomial'
#   preprocessor:polynomial:degree, Value: 2
#   preprocessor:polynomial:include_bias, Value: 'True'
#   preprocessor:polynomial:interaction_only, Value: 'True'
#   rescaling:__choice__, Value: 'standardize'
# You are already timing task: index_run5
# [ERROR] [2016-09-10 21:01:04,717:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Model only predicts at random: /tmp/autosklearn_tmp_20837_8258/.auto-sklearn/predictions_ensemble/predictions_ensemble_1_00001.npy has score: -0.016548463357
# [INFO] [2016-09-10 21:01:05,425:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble Selection:
# 	Trajectory: 0: 0.976359 1: 0.976359 2: 0.976359 3: 0.976359 4: 0.976359 5: 0.976359 6: 0.976359 7: 0.976359 8: 0.976359 9: 0.976359 10: 0.976359 11: 0.976359 12: 0.976359 13: 0.976359 14: 0.976359 15: 0.976359 16: 0.976359 17: 0.976359 18: 0.976359 19: 0.976359 20: 0.976359 21: 0.976359 22: 0.976359 23: 0.976359 24: 0.979737 25: 0.979737 26: 0.979737 27: 0.979737 28: 0.979737 29: 0.979737 30: 0.979737 31: 0.979737 32: 0.979737 33: 0.976359 34: 0.976359 35: 0.976359 36: 0.976359 37: 0.976359 38: 0.976359 39: 0.976359 40: 0.976359 41: 0.976359 42: 0.976359 43: 0.976359 44: 0.976359 45: 0.976359 46: 0.976359 47: 0.976359 48: 0.976359 49: 0.976359
# 	Members: [14, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 11, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 	Weights: [ 0.    0.    0.    0.    0.    0.    0.96  0.    0.    0.    0.    0.02
#   0.    0.    0.02  0.    0.    0.    0.    0.    0.  ]
# 	Identifiers: (1, 9) (1, 14) (1, 18)
# [INFO] [2016-09-10 21:01:05,430:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Training performance: 0.976359
# [INFO] [2016-09-10 21:01:05,432:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Building the ensemble took 0.716095 seconds
# [INFO] [2016-09-10 21:01:05,434:EnsembleBuilder(1):c78981c2110b7be62d8566d479ad1b7e] Ensemble output did not change.
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/pynisher/limit_function_call.py", line 83, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/ensemble_builder.py", line 145, in main
#     time.sleep(2)
# KeyboardInterrupt
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/pynisher/limit_function_call.py", line 83, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/evaluation/holdout_evaluator.py", line 148, in eval_holdout
#     loss, opt_pred, valid_pred, test_pred = evaluator.fit_predict_and_loss()
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/evaluation/holdout_evaluator.py", line 59, in fit_predict_and_loss
#     self.model.fit(X_train, Y_train)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/base.py", line 63, in fit
#     self.fit_estimator(X, y, **fit_params)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/base.py", line 138, in fit_estimator
#     self.pipeline_.steps[-1][-1].fit(X, y, **fit_params)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/pipeline/components/classification/adaboost.py", line 44, in fit
#     estimator.fit(X, Y, sample_weight=sample_weight)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py", line 405, in fit
#     return super(AdaBoostClassifier, self).fit(X, y, sample_weight)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py", line 140, in fit
#     sample_weight)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py", line 465, in _boost
#     return self._boost_discrete(iboost, X, y, sample_weight)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py", line 539, in _boost_discrete
#     estimator.fit(X, y, sample_weight=sample_weight)
#   File "/Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/tree/tree.py", line 350, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7bdd0885ba0a> in <module>()
#      14 y_test = y[1000:]
#      15 automl = autosklearn.classification.AutoSklearnClassifier()
# ---> 16 automl.fit(X_train, y_train)
#      17 print(automl.score(X_test,y_test))
#
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/estimators.py in fit(self, X, y, metric, feat_type, dataset_name)
#     269
#     270         return super(AutoSklearnClassifier, self).fit(X, y, task, metric,
# --> 271                                                       feat_type, dataset_name)
#     272
#     273     def predict(self, X):
#
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/automl.py in fit(self, X, y, task, metric, feat_type, dataset_name)
#     173                                             encode_labels=False)
#     174
# --> 175         return self._fit(loaded_data_manager)
#     176
#     177     def fit_automl_dataset(self, dataset):
#
# /Users/alex/anaconda/envs/p3/lib/python3.5/site-packages/autosklearn/automl.py in _fit(self, datamanager)
#     399         else:
#     400             for proc in procs:
# --> 401                 proc.join()
#     402
#     403         if self._queue is None:
#
# /Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/process.py in join(self, timeout)
#     119         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     120         assert self._popen is not None, 'can only join a started process'
# --> 121         res = self._popen.wait(timeout)
#     122         if res is not None:
#     123             _children.discard(self)
#
# /Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/popen_fork.py in wait(self, timeout)
#      49                     return None
#      50             # This shouldn't block if wait() returned successfully.
# ---> 51             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      52         return self.returncode
#      53
#
# /Users/alex/anaconda/envs/p3/lib/python3.5/multiprocessing/popen_fork.py in poll(self, flag)
#      27             while True:
#      28                 try:
# ---> 29                     pid, sts = os.waitpid(self.pid, flag)
#      30                 except OSError as e:
#      31                     # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
