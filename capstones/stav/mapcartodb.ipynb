# %%
import pandas as pd
import numpy as np
import shapely

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
geoms = pd.read_csv('/Users/Stav/Downloads/planning_neighborhoods.csv')
geoms.neighborho = geoms.neighborho.apply(lambda x: x.lower())

# %%
geoms.head()
# Out:
#    cartodb_id                                           the_geom  \
# 0           1  0106000020E61000000100000001030000000100000034...
# 1          12  0106000020E6100000010000000103000000010000001C...
# 2          20  0106000020E61000001100000001030000000400000000...
# 3          21  0106000020E610000002000000010300000001000000A9...
# 4          32  0106000020E6100000010000000103000000010000000E...
#
#        neighborho
# 0        seacliff
# 1  crocker amazon
# 2          marina
# 3         bayview
# 4        nob hill

# %%
from IPython.display import HTML
HTML('<iframe width="100%" height="520" frameborder="0" src="https://stavgrossfeld.cartodb.com/viz/f411c652-3cdf-11e6-8073-0ecfd53eb7d3/embed_map" \
     allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>')
# Out:
# <iframe width="100%" height="520" frameborder="0" src="https://stavgrossfeld.cartodb.com/viz/f411c652-3cdf-11e6-8073-0ecfd53eb7d3/embed_map"      allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>

# %%
map_choro = pd.read_csv('/Users/Stav/Downloads/new_geoms_2.csv')

# %%
map_choro
# Out:
#     cartodb_id                                           the_geom  field_1  \
# 0            1  0106000020E61000000100000001030000000100000034...        0
# 1           20  0106000020E61000001100000001030000000400000000...        1
# 2           21  0106000020E610000002000000010300000001000000A9...        2
# 3           34  0106000020E610000040000000010300000001000000D4...        4
# 4           25  0106000020E61000000100000001030000000100000032...        5
# 5           23  0106000020E6100000010000000103000000010000000C...       15
# 6           11  0106000020E61000000100000001030000000100000061...       19
# 7           29  0106000020E61000000100000001030000000100000045...       20
# 8           13  0106000020E61000000100000001030000000100000028...       21
# 9           16  0106000020E6100000010000000103000000010000002D...       23
# 10          32  0106000020E6100000010000000103000000010000000E...        3
# ...

# %%
#!pip install branca.colormap
from branca.colormap import linear

colormap = linear.YlOrRd.scale(
    1000,3500)
    #map_choro.price.max())

print(colormap(5.))

colormap
# Out:
# #ffffb2
# ...

# %%
price_dict = {}
for k,v in zip(map_choro['district1'],map_choro['price']):
    price_dict[k] = v

# %%
color_dict = {key: colormap(price_dict[key]) for key in price_dict.keys()}
color_dict
# Out:
# {'bayview': '#fec863',
#  'bernal heights': '#fea747',
#  'castro/upper market': '#feb54f',
#  'chinatown': '#ffe98e',
#  'diamond heights': '#e9251f',
#  'downtown/civic center': '#feb650',
#  'excelsior': '#fff6a4',
#  'financial district': '#b20026',
#  'glen park': '#fe9640',
#  'golden gate park': '#feae4a',
#  'haight ashbury': '#feb852',
#  'inner richmond': '#fec15b',
#  'inner sunset': '#b10026',
#  'lakeshore': '#fe923e',
#  'marina': '#fe9a42',
#  'mission district': '#fea847',
#  'nob hill': '#feb54f',
#  'noe valley': '#fe943f',
#  'north beach': '#fd853a',
#  'ocean view': '#fea345',
#  'outer mission': '#fec35e',
#  'outer richmond': '#fed673',
#  'outer sunset': '#febf59',
#  'pacific heights': '#fd582d',
#  'parkside': '#cf0f20',
#  'potrero hill': '#fd6831',
#  'presidio': '#fd7635',
#  'presidio heights': '#f13723',
#  'russian hill': '#fd7e37',
#  'seacliff': '#fec35e',
#  'south of market': '#b10026',
#  'twin peaks': '#fea245',
# ...

# %%
# %%html
# <style>
# .output_subarea svg {
#     font-size: 10pt !important;
#     color: #FFFFFF !important;
#     position: absolute;
#     top: 10px;
#     right: 30px;
#     color: white;
# }
#
# svg text {
#     color: white !important;
# }
#
# #legend-form {
#     position: absolute;
#     z-index: 2000;
#     top: 20px;
#         right: -500px;
#             color: white;
# }
# </style>
# Out:
# <style>
# .output_subarea svg {
#     font-size: 10pt !important;
#     color: #FFFFFF !important;
#     position: absolute;
#     top: 10px;
#     right: 30px;
#     color: white;
# }
#
# svg text {
#     color: white !important;
# }
#
# #legend-form {
#     position: absolute;
#     z-index: 2000;
#     top: 20px;
#         right: -500px;
#             color: white;
# }
# </style>

# %%
import folium
from folium import plugins

#Cartodb Dark_matter
m = folium.Map(location=[37.7599,-122.431297],tiles='Cartodb Dark_matter', zoom_start = 12, min_zoom = 12, max_zoom = 15)

folium.GeoJson(open('/Users/Stav/Downloads/new_geoms_2.geojson'),style_function=lambda feature:{'fillColor': color_dict[feature['properties']['district1']],'fillOpacity':'.5','color' : 'white','weight':'3','dashArray':'5,5'}).add_to(m)


colormap.caption = 'Rental price scale'

#map_osm.geo_json('./planning_neighborhoods.geojson',data = map_choro,  columns=['district1', 'price'],key_on='Features', fill_color = 'YlOrRd',line_color='red',line_weight=3, legend_name='Price ($)')

display(m)
# display(HTML("""
# <div style="position: absolute">
#     <div id='legend-form'>
#         <h4>rental price</h4>
#            <select name="something">
#                <option>price</option>
#                <option>crime</option>
#            </select>
#     </div>
# </div>
# """))

display(colormap)
colormap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
# ...

# %%
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb1;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb1;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#fffeb0;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#fffeaf;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#fffdaf;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#fffdae;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#fffcad;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#fffcac;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#fffbac;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#fffbab;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#fffaaa;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
#{i : colormap (color) for color in ([price_dict[i] for i in price_dict.keys()])}
#i

# %%
price_dict.keys()
# Out:
# ['seacliff',
#  'inner richmond',
#  'financial district',
#  'presidio',
#  'noe valley',
#  'western addition',
#  'north beach',
#  'outer richmond',
#  'haight ashbury',
#  'chinatown',
#  'castro/upper market',
#  'russian hill',
#  'parkside',
#  'twin peaks',
#  'golden gate park',
#  'lakeshore',
#  'downtown/civic center',
#  'nob hill',
#  'mission district',
#  'diamond heights',
#  'glen park',
#  'excelsior',
#  'outer sunset',
#  'marina',
#  'ocean view',
#  'presidio heights',
#  'bernal heights',
#  'south of market',
#  'potrero hill',
#  'pacific heights',
#  'west of twin peaks',
#  'inner sunset',
#  'outer mission',
#  'visitacion valley',
#  'bayview']

# %%
import json

with open('/Users/Stav/Downloads/new_geoms_2.geojson') as f:
    data = json.load(f)
print data['features'][0]['properties']['district1']
# Out:
# seacliff

# %%
price_dict
# Out:
# {'bayview': 1600,
#  'bernal heights': 1960,
#  'castro/upper market': 1800,
#  'chinatown': 1250,
#  'diamond heights': 2995,
#  'downtown/civic center': 1795,
#  'excelsior': 1100,
#  'financial district': 3495,
#  'glen park': 2150,
#  'golden gate park': 1880,
#  'haight ashbury': 1775,
#  'inner richmond': 1680,
#  'inner sunset': 4935,
#  'lakeshore': 2200,
#  'marina': 2100,
#  'mission district': 1950,
#  'nob hill': 1800,
#  'noe valley': 2175,
#  'north beach': 2300,
#  'ocean view': 2000,
#  'outer mission': 1650,
#  'outer richmond': 1450,
#  'outer sunset': 1700,
#  'pacific heights': 2600,
#  'parkside': 3250,
#  'potrero hill': 2495,
#  'presidio': 2400,
#  'presidio heights': 2850,
#  'russian hill': 2350,
#  'seacliff': 1650,
#  'south of market': 3500,
#  'twin peaks': 2015,
#  'visitacion valley': 2345,
#  'west of twin peaks': 1699,
#  'western addition': 1395}

# %%
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb1;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb1;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#fffeb0;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#fffeaf;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#fffdaf;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#fffdae;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#fffcad;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#fffcac;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#fffbac;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#fffbab;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#fffaaa;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
fig = plt.figure(colormap)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-445a0290cb89> in <module>()
# ----> 1 fig = plt.figure(colormap)
#
# /Users/Stav/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
#     500             num = allnums[inum]
#     501     else:
# --> 502         num = int(num)  # crude validation of num argument
#     503
#     504     figManager = _pylab_helpers.Gcf.get_fig_manager(num)
#
# TypeError: int() argument must be a string or a number, not 'LinearColormap'

# %%
a = colormap.render()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-03d4a3cd9a0f> in <module>()
# ----> 1 a = colormap.render()
#
# /Users/Stav/anaconda/lib/python2.7/site-packages/branca/colormap.pyc in render(self, **kwargs)
#     290         self.tick_labels = legend_scaler(self.index)
#     291
# --> 292         super(ColorMap, self).render(**kwargs)
#     293
#     294         figure = self.get_root()
#
# /Users/Stav/anaconda/lib/python2.7/site-packages/branca/element.pyc in render(self, **kwargs)
#     593         """Renders the HTML representation of the element."""
#     594         figure = self.get_root()
# --> 595         assert isinstance(figure, Figure), ("You cannot render this Element "
#     596                                             "if it's not in a Figure.")
#     597
#
# AssertionError: You cannot render this Element if it's not in a Figure.

# %%
colormap.tick_labels
# Out:
# [1000.0,
#  1416.6666666666665,
#  1833.3333333333333,
#  2250.0,
#  2666.6666666666665,
#  3083.3333333333335,
#  3500.0]

# %%
colormap.caption
# Out:
# 'Rental price scale'

# %%
import branca
from IPython.display import display, HTML

# %%
display(HTML("<div id='crap' style='position: relative 150px;'>"))
display(colormap)
display(HTML("</div>"))
# Out:
# <div id='crap' style='position: relative 150px;'>
# ...

# %%
# %%javascript
# console.log($('#crapb svg'))

# %%
f = Figure()
print f.render()
f.header.add_child(Element("<h1>Rental Price</h1>"))
f.width = 300
f.height = 100

#f.add_child(Element(Figure(colormap)))
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4af19f349c85> in <module>()
# ----> 1 f = Figure()
#       2 print f.render()
#       3 f.header.add_child(Element("<h1>Rental Price</h1>"))
#       4 f.width = 300
#       5 f.height = 100
#
# NameError: name 'Figure' is not defined

# %%
a = branca.element.Figure(colormap)

# %%
branca.colormap.legend_scaler = 'title'

# %%
from branca.element import *
e = Element('title')
e.render()
# Out:
# u'title'

# %%
branca.colormap
# Out:
# <module 'branca.colormap' from '/Users/Stav/anaconda/lib/python2.7/site-packages/branca/colormap.pyc'>

# %%
hello = price_dict.keys()

# %%
hello[0]
# Out:
# 'seacliff'

# %%
def test():
    print hello

# %%
from ipywidgets import *
from IPython.display import display

from ipywidgets import Dropdown


destination = Dropdown(
   options= hello,
   value = hello[0],
   description='price. District: ',
)


submit_button = Button(description="Submit Info")
submit_button.on_click(test)   # test is my mapping function

display(colormap)
display(destination)  # display destination


display(submit_button)   # display submit button

# after they submit destination.values
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffb2;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffb1;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffb1;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#fffeb0;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#fffeaf;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#fffdaf;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#fffdae;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#fffcad;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#fffcac;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#fffbac;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#fffbab;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#fffaaa;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
style_function
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-231-5e1048d027cc> in <module>()
# ----> 1 style_function
#
# NameError: name 'style_function' is not defined

# %%
crime = pd.read_csv('./SFPD_Incidents_-_from_1_January_2003.csv')

# %%
crime_sub = crime.sample(50000)

# %%
theft = ['LARCENY/THEFT','VEHICLE THEFT','BURGLARY','ROBBERY','STOLEN PROPERTY','RECOVERED VEHICLE']
drunk = ['DRUG/NARCOTIC','DRUNKENNESS','LIQOUR LAWS','DRIVING UNDER THE INFLUENCE','LIQUOR LAWS']
organized = ['BRIBERY','EXTORTION','PROSTITUTION']
violent = ['ASSAULT','SEX OFFENSES, FORCIBLE','KIDNAPPING']
narcotic = ['DRUG/NARCOTIC']
city = ['VANDALISM','LOITERING']

crime_sub['is_theft'] = crime_sub.Category.apply(lambda x: 1 if x in theft else 0)
crime_sub['is_drunk'] = crime_sub.Category.apply(lambda x: 1 if x in drunk else 0)
crime_sub['is_organized'] = crime_sub.Category.apply(lambda x: 1 if x in organized else 0)
crime_sub['is_violent'] = crime_sub.Category.apply(lambda x: 1 if x in violent else 0)
crime_sub['is_narcotic'] = crime_sub.Category.apply(lambda x: 1 if x in narcotic else 0)
crime_sub['is_city'] = crime_sub.Category.apply(lambda x: 1 if x in city else 0)

# %%
crime_sub.head()
# Out:
#          IncidntNum         Category  \
# 1280344    50865092    DRUG/NARCOTIC
# 1855649   160201102  STOLEN PROPERTY
# 860282     50547096     NON-CRIMINAL
# 177771    150423811   OTHER OFFENSES
# 886023     80996219     NON-CRIMINAL
#
#                                                   Descript  DayOfWeek  \
# 1280344                     POSSESSION OF METH-AMPHETAMINE  Wednesday
# 1855649  STOLEN PROPERTY, POSSESSION WITH KNOWLEDGE, RE...  Wednesday
# 860282                                       LOST PROPERTY   Thursday
# 177771                                    RESISTING ARREST     Friday
# 886023                                       LOST PROPERTY   Thursday
#
#                Date   Time  PdDistrict      Resolution  \
# 1280344  08/03/2005  01:01     MISSION  ARREST, BOOKED
# 1855649  03/09/2016  02:56    NORTHERN  ARREST, BOOKED
# 860282   05/19/2005  02:00     CENTRAL            NONE
# 177771   05/15/2015  18:43  TENDERLOIN  ARREST, BOOKED
# ...

# %%
from datetime import datetime as dt
print crime_sub.index.dtype
crime_sub['Date'] = pd.to_datetime(crime_sub['Date'])
crime_sub.set_index('Date',inplace= True)
print crime_sub.index.dtype

# create a year function, 2016 is not completely represented
crime_sub['year'] = crime_sub.index.map(lambda val: val.year)
crime_sub.head(1)
crime_sub = crime_sub[crime_sub['year'] < 2016]
# Out:
# int64
# datetime64[ns]

# %%
theft = crime_sub[crime_sub.is_theft == 1]

# %%
theft.head()
# Out:
#             IncidntNum         Category  \
# Date
# 2004-06-02    40635714    LARCENY/THEFT
# 2003-05-16    30601305    LARCENY/THEFT
# 2013-12-10   131039394         BURGLARY
# 2005-11-03    51243003         BURGLARY
# 2006-03-28    60331782  STOLEN PROPERTY
#
#                                                Descript  DayOfWeek   Time  \
# Date
# 2004-06-02                       GRAND THEFT AUTO STRIP  Wednesday  20:00
# 2003-05-16               PETTY THEFT FROM UNLOCKED AUTO     Friday  19:00
# 2013-12-10  BURGLARY OF APARTMENT HOUSE, FORCIBLE ENTRY    Tuesday  11:36
# 2005-11-03        BURGLARY OF RESIDENCE, FORCIBLE ENTRY   Thursday  08:15
# 2006-03-28                    RECEIVING STOLEN PROPERTY    Tuesday  03:04
#
#            PdDistrict      Resolution                    Address           X  \
# Date
# 2004-06-02    TARAVAL            NONE       200 Block of FONT BL -122.475285
# 2003-05-16   NORTHERN            NONE     PIERCE ST / LOMBARD ST -122.439337
# ...

# %%
theft = theft.reset_index()

# %%
str(theft.Date[0]).split()[0]
# Out:
# '2004-06-02'

# %%
from folium.map import Popup, Icon, Marker
import folium
from folium import plugins

#Cartodb Dark_matter
m = folium.Map(location=[37.7599,-122.431297],tiles='Cartodb Dark_matter', zoom_start = 12, min_zoom = 12, max_zoom = 15)

folium.GeoJson(open('/Users/Stav/Downloads/new_geoms_2.geojson'),style_function=lambda feature:{'fillColor': color_dict[feature['properties']['district1']],'fillOpacity':'.5','color' : 'white','weight':'3','dashArray':'5,5'}).add_to(m)

marker_cluster = folium.MarkerCluster("Theft").add_to(m)

for each in theft[0:1000].iterrows():
    #print each[1]['Category'], each[1]['DayOfWeek'], each['Time']
    popup = str('crime: ' + each[1]['Category'] + '\n' + 'date: ' + str(each[1]['Date']).split()[0] + '\n'  'day: '  + each[1]['DayOfWeek'] + '\n' + 'time: ' + each[1]['Time'])
    folium.Marker(location = [each[1]['Y'],each[1]['X']],popup=popup).add_to(marker_cluster)
    
    
    
    
display(m)
display(colormap)
# display(HTML("""
# <div style="position: absolute">
#     <div id='legend-form'>
#         <h4>rental price</h4>
#            <select name="something">
#                <option>price</option>
#                <option>crime</option>
#            </select>
#     </div>
# </div>
# """))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
# ...

# %%
add_marker(location = [each[1]['Y'],each[1]['X']], radius = 200, line_color='#3186cc',fill_color='#3186cc').add_to(marker_cluster)

# %%
m.circle_marker(location = [each[1]['Y'],each[1]['X']], radius = 200, line_color='#3186cc',fill_color='#3186cc')

# %%
#http://deparkes.co.uk/2016/06/24/folium-marker-clusters/
