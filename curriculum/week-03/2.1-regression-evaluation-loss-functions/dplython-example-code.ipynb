# %%
import pandas as pd
import numpy as np
from dplython import (DplyFrame, X, diamonds, select, sift, sample_n,
    sample_frac, head, arrange, mutate, group_by, summarize, DelayFunction)

# %%
combine = DplyFrame(pd.read_csv('./combine.csv'))

# %%
combine.head()
# Out:
#      id  Year             Name Position  HeightFeet  HeightInches  Weight  \
# 0  8984  2013  Quanterus Smith       DE           6           5.0     250
# 1  9002  2013       Abry Jones       DT           6           3.0     313
# 2  9004  2013     Bennie Logan       DT           6           2.0     309
# 3  9012  2013      John Boyett       FS           5          10.0     204
# 4  9018  2013    Bacarri Rambo       FS           6           0.0     211
#
#     Arms   Hands  FortyYD    ...     Bench  Round           College     Pick  \
# 0  33.25  10.375      0.0    ...         0      5  Western Kentucky  13(146)
# 1  35.00   9.750      0.0    ...        30      0               NaN      NaN
# 2  34.00  10.250      0.0    ...        30      3               LSU    5(67)
# 3  30.50   8.500      0.0    ...        27      6            Oregon  24(192)
# 4  31.00   9.250      0.0    ...        17      6           Georgia  23(191)
#
#    PickRound  PickTotal  FirstName  LastName HeightInchesTotal Wonderlic
# 0         13        146  Quanterus     Smith              77.0         0
# 1          0          0       Abry     Jones              75.0         0
# 2          5         67     Bennie     Logan              74.0         0
# 3         24        192       John    Boyett              70.0         0
# 4         23        191    Bacarri     Rambo              72.0         0
#
# [5 rows x 26 columns]

# %%
# Select specific columns of the DataFrame using select, and 
# get the first few using head
tmp = combine >> select(X.Position, X.Weight, X.Hands)
print tmp.shape
tmp.head()
# Out:
# (4625, 3)
#   Position  Weight   Hands
# 0       DE     250  10.375
# 1       DT     313   9.750
# 2       DT     309  10.250
# 3       FS     204   8.500
# 4       FS     211   9.250

# %%
# Filter out rows using sift
tmp = combine >> sift(X.Weight < 200) >> select(X.Position, X.Weight, X.Hands, X.PickTotal)
print tmp.shape
tmp.head()
# Out:
# (797, 4)
#    Position  Weight  Hands  PickTotal
# 15       CB     182  9.375        123
# 49       RB     193  0.000          0
# 55       WR     192  9.000         54
# 56       CB     183  9.000          0
# 58       CB     190  0.000        156

# %%
# Sample with sample_n or sample_frac,
tmp = (combine >> 
       sample_n(10) >>
       select(X.Position, X.Weight, X.Hands, X.PickTotal))

print tmp.shape
tmp
# Out:
# (10, 4)
#      Position  Weight  Hands  PickTotal
# 95         OT     316  0.000          0
# 29         OG     319  0.000        178
# 4405       OT     309  0.000        156
# 2815      OLB     258  0.000          0
# 3079       TE     264  0.000        181
# 2990       DE     269  0.000          0
# 3986       OC     302  0.000          0
# 811        RB     210  9.000          0
# 155        CB     193  9.625         24
# 3501       DT     300  0.000        139

# %%
# sort with arrange
tmp = (combine >> 
       sample_n(10) >>
       arrange(X.Weight) >> 
       select(X.Position, X.Weight, X.Hands, X.PickTotal))
tmp
# Out:
#      Position  Weight   Hands  PickTotal
# 129        RB     197   0.000         24
# 1071       WR     204   9.375        128
# 949        RB     204   0.000        172
# 119        SS     210   0.000          0
# 13         QB     231   9.125        234
# 3154       TE     238   0.000          0
# 3143       TE     249   0.000        104
# 3047      ILB     251   0.000          0
# 6          OC     302  10.250        121
# 4611       OG     367   0.000          0

# %%
# You can: 
# add columns with mutate (referencing other columns!)
# group rows into dplyr-style groups with group_by
# collapse rows into single rows using sumarize
tmp = (combine >> 
       sample_n(10) >>
       mutate(mean_of_weight_hands=(X.Weight+X.Hands)/2.) >> 
       select(X.Position, X.Weight, X.Hands, X.PickTotal, X.mean_of_weight_hands))
tmp
# Out:
#      Position  Weight  Hands  PickTotal  mean_of_weight_hands
# 811        RB     210    9.0          0                 109.5
# 312        CB     178    0.0         31                  89.0
# 2975       DE     249    0.0          7                 124.5
# 2586       DE     264    0.0        103                 132.0
# 3805       DT     305    0.0        154                 152.5
# 3971       DT     315    0.0        190                 157.5
# 1182       FS     199    0.0        114                  99.5
# 873       ILB     245    0.0        154                 122.5
# 4371       OT     290    0.0          0                 145.0
# 1030       FS     190    0.0          0                  95.0

# %%
# group by columns
tmp = (combine >>
       group_by(X.Position, X.Year) >> 
       summarize(avg_weight=X.Weight.mean()) >>
       arrange(X.Year, X.Position))
tmp.head(10)
# Out:
#     Position  Year  avg_weight
# 1         CB  1999  184.807692
# 17        DE  1999  269.156250
# 33        DT  1999  295.733333
# 49        FB  1999  236.583333
# 63        FS  1999  199.882353
# 79       ILB  1999  242.840000
# 98        OC  1999  304.733333
# 113       OG  1999  311.724138
# 129      OLB  1999  239.923077
# 145       OT  1999  321.531250

# %%
# To pass the DataFrame or columns into functions, apply @DelayFunction
@DelayFunction
def MeanOfColumns(df):
    meancol = df.mean(axis=1)
    return meancol

tmp = (combine >>
       select(X.Year, X.Weight, X.Hands) >>
       mutate(Mean_of_cols = (combine >> 
                              select(X.Year, X.Weight, X.Hands) >> 
                              MeanOfColumns(X))))
tmp
# Out:
#       Year  Weight   Hands  Mean_of_cols
# 0     2013     250  10.375    757.791667
# 1     2013     313   9.750    778.583333
# 2     2013     309  10.250    777.416667
# 3     2013     204   8.500    741.833333
# 4     2013     211   9.250    744.416667
# 5     2013     243  10.500    755.500000
# 6     2013     302  10.250    775.083333
# 7     2013     332   9.875    784.958333
# 8     2013     320   9.750    780.916667
# 9     2013     243   9.375    755.125000
# 10    2013     331   9.625    784.541667
# 11    2013     318  10.625    780.541667
# 12    2013     315  10.250    779.416667
# 13    2013     231   9.125    751.041667
# 14    2013     221   9.875    747.958333
# 15    2012     182   9.375    734.458333
# 16    2012     270   9.750    763.916667
# 17    2012     268  10.125    763.375000
# 18    2012     243  10.250    755.083333
# 19    2012     268   0.000    760.000000
# 20    2012     316   0.000    776.000000
# 21    2012     291   9.625    770.875000
# 22    2012     306   0.000    772.666667
# 23    2012     309   9.125    776.708333
# 24    2012     314  10.000    778.666667
# 25    2012     315   0.000    775.666667
# 26    2012     207   9.250    742.750000
# 27    2012     314   9.250    778.416667
# 28    2012     298   0.000    770.000000
# 29    2012     319   0.000    777.000000
# ...    ...     ...     ...           ...
# 4595  2007     315   0.000    774.000000
# 4596  2005     321   0.000    775.333333
# 4597  2000     320   0.000    773.333333
# 4598  2003     334   0.000    779.000000
# 4599  2005     317   0.000    774.000000
# 4600  2013     328   9.625    783.541667
# 4601  2000     318   0.000    772.666667
# 4602  2000     309   0.000    769.666667
# 4603  2012     325   0.000    779.000000
# 4604  2012     320  10.125    780.708333
# 4605  2004     311   0.000    771.666667
# 4606  2011     308  10.250    776.416667
# 4607  1999     314   0.000    771.000000
# 4608  2005     312   0.000    772.333333
# 4609  2010     349  11.000    790.000000
# 4610  2006     339   0.000    781.666667
# 4611  1999     367   0.000    788.666667
# 4612  1999     302   0.000    767.000000
# 4613  2010     320   9.750    779.916667
# 4614  1999     324   0.000    774.333333
# 4615  2012     338   0.000    783.333333
# 4616  2004     316   0.000    773.333333
# 4617  2003     324   0.000    775.666667
# 4618  2004     306   0.000    770.000000
# 4619  1999     354   0.000    784.333333
# 4620  2000     338   0.000    779.333333
# 4621  2007     319   0.000    775.333333
# 4622  2011     300   9.375    773.458333
# 4623  2001     348   0.000    783.000000
# 4624  2004     316   0.000    773.333333
#
# [4625 rows x 4 columns]
