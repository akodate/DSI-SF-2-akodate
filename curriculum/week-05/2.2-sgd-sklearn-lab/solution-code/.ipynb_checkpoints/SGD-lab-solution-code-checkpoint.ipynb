# %% [markdown]
# # sklearn and stochastic gradient descent
#
# Until now we've been using the more standard LassoCV, RidgeCV, etc. (or GridSearchCV) to find our optimal parameters. Unfortunately, though these methods work well on smaller datasets with relatively small numbers of columns, once you start getting into "Medium Data" these slow down to a crawl, and take up so much memory that fitting them becomes untenable.
#
# This is where stochastic gradient descent comes in. Because of its ability to fit iteratively on portions of the data, it avoids the issue of large datasets. It is the most common algorithm to fit models on large datasets.
#
# ---
#
# ### Import the packages

# %%
import numpy as np
import scipy 
import seaborn as sns
import pandas as pd

import patsy

import matplotlib
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %% [markdown]
# ---
#
# ### Load the data
#
# I've provided data from the SF assessor's office on housing prices in San Francisco - already cleaned up. However, if you want to try this out on data you've been having trouble fitting, such as the Yelp data for project 5, feel free!

# %%
prop = pd.read_csv('/Users/alex/Desktop/DSI-SF-2-akodate/datasets/sf_assessor_value/assessor_value_cleaned.csv')

# %%
prop.dtypes
# Out:
# baths               int64
# beds                int64
# lot_depth         float64
# basement_area     float64
# front_ft          float64
# owner_pct         float64
# rooms               int64
# property_class     object
# neighborhood       object
# tax_rate          float64
# volume              int64
# sqft                int64
# stories             int64
# year_recorded       int64
# year_built          int64
# zone               object
# value             float64
# dtype: object

# %% [markdown]
# ---
#
# ### Sample down the data
#
# For demonstration purposes and the sake of speed, I am sampling down this large dataset to a more reasonable amount of rows.
#
# Stochastic gradient descent is much faster, but the real benefit in my opinion is that it can fit much larger datasets. That being said, it is still slow to fit on huge datasets in sklearn. I don't recommend fitting on the entire data. This is actually my recommendation in general; finding the optimal parameters with more and more data will change the hyperparameters but often with marginal returns.

# %%
prop_samp = prop.sample(frac=0.05)

# %% [markdown]
# ---
#
# ### SGD with regression
#
# Below I set up X, y data predicting value (housing price) from the remaining variables. There are ~75,000 rows, with 170 columns.

# %%
f = 'value ~ '+' + '.join([c for c in prop_samp.columns if not c == 'value'])+' -1'
print f
y, X = patsy.dmatrices(f, data=prop_samp, return_type='dataframe')
y = y.values.ravel()

print y.shape, X.shape
# Out:
# value ~ baths + beds + lot_depth + basement_area + front_ft + owner_pct + rooms + property_class + neighborhood + tax_rate + volume + sqft + stories + year_recorded + year_built + zone -1
# (37707,) (37707, 168)

# %% [markdown]
# ---
#
# ### Import the modeling classes
#
# `SGDRegressor` and `SGDClassifer` are the models used in this solution These are the very general, flexible stochastic gradient descent classes.

# %%
from sklearn.linear_model import (LinearRegression, LogisticRegression, 
                                  Lasso, Ridge,
                                  SGDRegressor, SGDClassifier)
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV

import scipy.stats as stats

# %% [markdown]
# ---
#
# ### Standardize the data
#
# Always a necessary step when performing regularization.

# %%
ss = StandardScaler()
Xn = ss.fit_transform(X)
print Xn.shape
# Out:
# (37707, 168)

# %% [markdown]
# ---
#
# ### Run the gridsearch on parameters
#
# SGDRegressor and SGDClassifier use GridSearchCV and RandomizedSearchCV (which will be introduced in the next section) to find the optimal parameters. If you are still unsure of how to use the GridSearchCV, please look this up in the sklearn documentation. I want you to get used to looking things up online - you will be doing this literally every day on the job.

# %%
sgd_params = {
    'loss':['squared_loss'],
    'penalty':['l1','l2'],
    'alpha':np.linspace(0.01, 10000, 100)
}

sgd_reg = SGDRegressor()
sgd_reg_gs = GridSearchCV(sgd_reg, sgd_params, cv=5, verbose=2)

# %%
sgd_reg_gs.fit(Xn, y)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV] penalty=l1, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l1, alpha=0.01, loss=squared_loss -   0.4s
# [CV] penalty=l1, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l1, alpha=0.01, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l1, alpha=0.01, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l1, alpha=0.01, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l1, alpha=0.01, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l2, alpha=0.01, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l2, alpha=0.01, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l2, alpha=0.01, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l2, alpha=0.01, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=0.01, loss=squared_loss .......................
# [CV] .............. penalty=l2, alpha=0.01, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=101.02, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=101.02, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=101.02, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=101.02, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=101.02, loss=squared_loss -   0.3s
# [CV] penalty=l2, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=101.02, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=101.02, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=101.02, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=101.02, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=101.02, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=101.02, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=202.03, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=202.03, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=202.03, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=202.03, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=202.03, loss=squared_loss -   0.3s
# [CV] penalty=l2, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=202.03, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=202.03, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=202.03, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=202.03, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=202.03, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=202.03, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=303.04, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=303.04, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=303.04, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=303.04, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=303.04, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=303.04, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=303.04, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=303.04, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=303.04, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=303.04, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=303.04, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=404.05, loss=squared_loss .....................
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:    8.2s
# [CV] ............ penalty=l1, alpha=404.05, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=404.05, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=404.05, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=404.05, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=404.05, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=404.05, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=404.05, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=404.05, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=404.05, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=404.05, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=404.05, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=505.06, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=505.06, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=505.06, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=505.06, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=505.06, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=505.06, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=505.06, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=505.06, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=505.06, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=505.06, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=505.06, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=606.07, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=606.07, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=606.07, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=606.07, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=606.07, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=606.07, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=606.07, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=606.07, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=606.07, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=606.07, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=606.07, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=707.08, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=707.08, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=707.08, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=707.08, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=707.08, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=707.08, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=707.08, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=707.08, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=707.08, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=707.08, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=707.08, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=808.09, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=808.09, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=808.09, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=808.09, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=808.09, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=808.09, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=808.09, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=808.09, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=808.09, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=808.09, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=808.09, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l1, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l1, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l1, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l1, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l1, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l2, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l2, alpha=909.1, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l2, alpha=909.1, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l2, alpha=909.1, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=909.1, loss=squared_loss ......................
# [CV] ............. penalty=l2, alpha=909.1, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1010.11, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1010.11, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1111.12, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1111.12, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1111.12, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1111.12, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1111.12, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1111.12, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1111.12, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1111.12, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1111.12, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1111.12, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1111.12, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1212.13, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1212.13, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1212.13, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1212.13, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1212.13, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1212.13, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1212.13, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1212.13, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1212.13, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1212.13, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1212.13, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1313.14, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1313.14, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1313.14, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1313.14, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1313.14, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1313.14, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1313.14, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1313.14, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1313.14, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1313.14, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1313.14, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1414.15, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1414.15, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1414.15, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1414.15, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1414.15, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1414.15, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1414.15, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1414.15, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1414.15, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1414.15, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1414.15, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1515.16, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1515.16, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1515.16, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1515.16, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1515.16, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1515.16, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1515.16, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1515.16, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1515.16, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1515.16, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1515.16, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1616.17, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=1616.17, loss=squared_loss ....................
# [Parallel(n_jobs=1)]: Done 161 tasks       | elapsed:   30.0s
# [CV] ........... penalty=l1, alpha=1616.17, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1616.17, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1616.17, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1616.17, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1616.17, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1616.17, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1616.17, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1616.17, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1616.17, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1616.17, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1717.18, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1717.18, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1717.18, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1717.18, loss=squared_loss -   0.4s
# [CV] penalty=l1, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1717.18, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1717.18, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1717.18, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1717.18, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1717.18, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1717.18, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1717.18, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1818.19, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1818.19, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1818.19, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1818.19, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=1818.19, loss=squared_loss -   0.3s
# [CV] penalty=l2, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1818.19, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1818.19, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1818.19, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1818.19, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1818.19, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=1818.19, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=1919.2, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=1919.2, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=1919.2, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=1919.2, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=1919.2, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=1919.2, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=1919.2, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=1919.2, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=1919.2, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=1919.2, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=1919.2, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2020.21, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2020.21, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2020.21, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2020.21, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2020.21, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2020.21, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2020.21, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2020.21, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2020.21, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2020.21, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2020.21, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2121.22, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2121.22, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2121.22, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2121.22, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2121.22, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2121.22, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2121.22, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2121.22, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2121.22, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2121.22, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2121.22, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2222.23, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2222.23, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2222.23, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2222.23, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2222.23, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2222.23, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2222.23, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2222.23, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2222.23, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2222.23, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2222.23, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2323.24, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2323.24, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2323.24, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2323.24, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2323.24, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2323.24, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2323.24, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2323.24, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2323.24, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2323.24, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2323.24, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2424.25, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2424.25, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2424.25, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2424.25, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2424.25, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2424.25, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2424.25, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2424.25, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2424.25, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2424.25, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2424.25, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2525.26, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2525.26, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2525.26, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2525.26, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2525.26, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2525.26, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2525.26, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2525.26, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2525.26, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2525.26, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2525.26, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2626.27, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2626.27, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2626.27, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2626.27, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2626.27, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2626.27, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2626.27, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2626.27, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2626.27, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2626.27, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2626.27, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2727.28, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2727.28, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2727.28, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2727.28, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2727.28, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2727.28, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2727.28, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2727.28, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2727.28, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2727.28, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2727.28, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2828.29, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2828.29, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2828.29, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2828.29, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=2828.29, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2828.29, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2828.29, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2828.29, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2828.29, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2828.29, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=2828.29, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=2929.3, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=2929.3, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=2929.3, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=2929.3, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=2929.3, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=2929.3, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=2929.3, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=2929.3, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=2929.3, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=2929.3, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=2929.3, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3030.31, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3030.31, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3030.31, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3030.31, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3030.31, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3030.31, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3030.31, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3030.31, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3030.31, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3030.31, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3030.31, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3131.32, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3131.32, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3131.32, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3131.32, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3131.32, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3131.32, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3131.32, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3131.32, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3131.32, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3131.32, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3131.32, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3232.33, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3232.33, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3232.33, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3232.33, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3232.33, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3232.33, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3232.33, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3232.33, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3232.33, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3232.33, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3232.33, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=3333.34, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3333.34, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3333.34, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3333.34, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=3333.34, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3333.34, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3333.34, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3333.34, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=3333.34, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=3333.34, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=3333.34, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=3333.34, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=3333.34, loss=squared_loss ....................
# ...
# [CV] ............ penalty=l1, alpha=8989.9, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=8989.9, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l1, alpha=8989.9, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=8989.9, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=8989.9, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=8989.9, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=8989.9, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8989.9, loss=squared_loss .....................
# [CV] ............ penalty=l2, alpha=8989.9, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9090.91, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9090.91, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9090.91, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9090.91, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9090.91, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9090.91, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9090.91, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9090.91, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9090.91, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9090.91, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9090.91, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9191.92, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9191.92, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9191.92, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9191.92, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9191.92, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9191.92, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9191.92, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9191.92, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9191.92, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9191.92, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9191.92, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9292.93, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9292.93, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9292.93, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9292.93, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9292.93, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9292.93, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9292.93, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9292.93, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9292.93, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9292.93, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9292.93, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9393.94, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9393.94, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9393.94, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9393.94, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9494.95, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9494.95, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9494.95, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9494.95, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9494.95, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9494.95, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9494.95, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9494.95, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9494.95, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9494.95, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9494.95, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9595.96, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9595.96, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9595.96, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9595.96, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9595.96, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9595.96, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9595.96, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9595.96, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9595.96, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9595.96, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9595.96, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9696.97, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9696.97, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9696.97, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9696.97, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9696.97, loss=squared_loss -   0.3s
# [CV] penalty=l2, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9696.97, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9696.97, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9696.97, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9696.97, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9696.97, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9696.97, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9797.98, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9797.98, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9797.98, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9797.98, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9797.98, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9898.99, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9898.99, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9898.99, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=9898.99, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=10000.0, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=10000.0, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=10000.0, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=10000.0, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l1, alpha=10000.0, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=10000.0, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=10000.0, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=10000.0, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=10000.0, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10000.0, loss=squared_loss ....................
# [CV] ........... penalty=l2, alpha=10000.0, loss=squared_loss -   0.1s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:  3.1min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=5, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'loss': ['squared_loss'], 'alpha': array([  1.00000e-02,   1.01020e+02, ...,   9.89899e+03,   1.00000e+04])},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=2)

# %%
print sgd_reg_gs.best_params_
print sgd_reg_gs.best_score_
sgd_reg = sgd_reg_gs.best_estimator_
# Out:
# {'penalty': 'l2', 'alpha': 101.02, 'loss': 'squared_loss'}
# 0.0120289938767

# %%
sgd_reg_gs_params = sgd_reg_gs.get_params()
sgd_reg_gs_params
# Out:
# {'cv': 5,
#  'error_score': 'raise',
#  'estimator': SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#         fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#         loss='squared_loss', n_iter=5, penalty='l2', power_t=0.25,
#         random_state=None, shuffle=True, verbose=0, warm_start=False),
#  'estimator__alpha': 0.0001,
#  'estimator__average': False,
#  'estimator__epsilon': 0.1,
#  'estimator__eta0': 0.01,
#  'estimator__fit_intercept': True,
#  'estimator__l1_ratio': 0.15,
#  'estimator__learning_rate': 'invscaling',
#  'estimator__loss': 'squared_loss',
#  'estimator__n_iter': 5,
#  'estimator__penalty': 'l2',
#  'estimator__power_t': 0.25,
#  'estimator__random_state': None,
#  'estimator__shuffle': True,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'fit_params': {},
#  'iid': True,
#  'n_jobs': 1,
#  'param_grid': {'alpha': array([  1.00000000e-02,   1.01020000e+02,   2.02030000e+02,
#            3.03040000e+02,   4.04050000e+02,   5.05060000e+02,
#            6.06070000e+02,   7.07080000e+02,   8.08090000e+02,
#            9.09100000e+02,   1.01011000e+03,   1.11112000e+03,
#            1.21213000e+03,   1.31314000e+03,   1.41415000e+03,
#            1.51516000e+03,   1.61617000e+03,   1.71718000e+03,
#            1.81819000e+03,   1.91920000e+03,   2.02021000e+03,
#            2.12122000e+03,   2.22223000e+03,   2.32324000e+03,
#            2.42425000e+03,   2.52526000e+03,   2.62627000e+03,
#            2.72728000e+03,   2.82829000e+03,   2.92930000e+03,
#            3.03031000e+03,   3.13132000e+03,   3.23233000e+03,
#            3.33334000e+03,   3.43435000e+03,   3.53536000e+03,
#            3.63637000e+03,   3.73738000e+03,   3.83839000e+03,
#            3.93940000e+03,   4.04041000e+03,   4.14142000e+03,
#            4.24243000e+03,   4.34344000e+03,   4.44445000e+03,
#            4.54546000e+03,   4.64647000e+03,   4.74748000e+03,
#            4.84849000e+03,   4.94950000e+03,   5.05051000e+03,
#            5.15152000e+03,   5.25253000e+03,   5.35354000e+03,
#            5.45455000e+03,   5.55556000e+03,   5.65657000e+03,
#            5.75758000e+03,   5.85859000e+03,   5.95960000e+03,
#            6.06061000e+03,   6.16162000e+03,   6.26263000e+03,
#            6.36364000e+03,   6.46465000e+03,   6.56566000e+03,
#            6.66667000e+03,   6.76768000e+03,   6.86869000e+03,
#            6.96970000e+03,   7.07071000e+03,   7.17172000e+03,
#            7.27273000e+03,   7.37374000e+03,   7.47475000e+03,
#            7.57576000e+03,   7.67677000e+03,   7.77778000e+03,
#            7.87879000e+03,   7.97980000e+03,   8.08081000e+03,
#            8.18182000e+03,   8.28283000e+03,   8.38384000e+03,
#            8.48485000e+03,   8.58586000e+03,   8.68687000e+03,
#            8.78788000e+03,   8.88889000e+03,   8.98990000e+03,
#            9.09091000e+03,   9.19192000e+03,   9.29293000e+03,
#            9.39394000e+03,   9.49495000e+03,   9.59596000e+03,
#            9.69697000e+03,   9.79798000e+03,   9.89899000e+03,
#            1.00000000e+04]),
#   'loss': ['squared_loss'],
#   'penalty': ['l1', 'l2']},
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'scoring': None,
#  'verbose': 2}

# %% [markdown]
# ---
#
# ### Visualize or otherwise look at the SGDRegression results
#
# How you choose to examine the results is up to you. Visualizations are always a good idea, but not entirely neccessary (or easy) in this case.

# %%
def lasso_coefs(X, Y, alphas):
    coefs = []
    lasso_reg = Lasso()
    for a in alphas:
        lasso_reg.set_params(alpha=a)
        lasso_reg.fit(X, Y)
        coefs.append(lasso_reg.coef_)
        
    return coefs

sgd_reg_alphas = sgd_reg_gs_params['param_grid']['alpha']
lcoefs = lasso_coefs(Xn, y, sgd_reg_alphas)
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)

# %%
# Plot the coefficients across alpha values:
fig, ax = plt.subplots(figsize=(11,7))

ax.plot(sgd_reg_alphas, lcoefs, lw=1.5)

ax.axvline(sgd_reg_gs.best_params_['alpha'], lw=1.5, ls='dashed', label='best alpha')

ax.set_title('GridSearchCV coef values across alphas')
ax.set_xlabel('alpha')
ax.set_ylabel('coef value')

plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ---
#
# ### RandomizedSearchCV
#
# This class is very similar to GridSearchCV in the way it is initialized with parameters. The big difference is that instead of searching across a strictly specified grid, it searches over random values that are defined by distributions.
#
# Below I have set up for you an example of parameters and calls to the class.
#
#     uniform: this random variable is from scipy.stats and it pulls random values from the uniform distribution from 0.01 to 20000
#     sgd_rand_params: the only difference here is that alpha gets the random variable. It will pull random values from that distribution
#     RandomizedSearchCV: this takes an n_iter parameter that specifies how long to search over random values
#
# RandomizedSearchCV is often faster than GridSearchCV while getting the same optimal parameteres. However, this is not _always_ the case. As far as I know it is not completely random, but rather begins to favor values that are closer to its current optimum.
#
# For more information, see:
#
# [RandomizedSearchCV documentation](http://scikit-learn.org/stable/modules/generated/sklearn.grid_search.RandomizedSearchCV.html#sklearn.grid_search.RandomizedSearchCV)
#
# [scipy.stats available distributions and functions](http://docs.scipy.org/doc/scipy/reference/stats.html)

# %%
uniform = stats.uniform(loc=0.01, scale=20000)

sgd_rand_params = {
    'loss':['squared_loss'],
    'penalty':['l1','l2'],
    'alpha':uniform
}

sgd_reg = SGDRegressor()
sgd_reg_rand_gs = RandomizedSearchCV(sgd_reg, sgd_rand_params, cv=5, verbose=2, n_iter=50)

# %%
sgd_reg_rand_gs.fit(Xn, y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] penalty=l1, alpha=18285.8419478, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18285.8419478, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18285.8419478, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18285.8419478, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18285.8419478, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18285.8419478, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18285.8419478, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18285.8419478, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18285.8419478, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18285.8419478, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=8358.32440604, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8358.32440604, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8358.32440604, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8358.32440604, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8358.32440604, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8358.32440604, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8358.32440604, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8358.32440604, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8358.32440604, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8358.32440604, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8685.19330266, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8685.19330266, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8685.19330266, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8685.19330266, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8685.19330266, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8685.19330266, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8685.19330266, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8685.19330266, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8685.19330266, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8685.19330266, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=15767.4453568, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=15767.4453568, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=15767.4453568, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=15767.4453568, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=15767.4453568, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=15767.4453568, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=15767.4453568, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=15767.4453568, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=15767.4453568, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=15767.4453568, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=4113.93225944, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=4113.93225944, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=4113.93225944, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=4113.93225944, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=4113.93225944, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=4113.93225944, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=4113.93225944, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=4113.93225944, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=4113.93225944, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=4113.93225944, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=13295.3506218, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13295.3506218, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13295.3506218, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13295.3506218, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13295.3506218, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13295.3506218, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13295.3506218, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13295.3506218, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13295.3506218, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13295.3506218, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4965.53539905, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4965.53539905, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4965.53539905, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4965.53539905, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4965.53539905, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4965.53539905, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4965.53539905, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4965.53539905, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4965.53539905, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4965.53539905, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12802.0717946, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12802.0717946, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12802.0717946, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12802.0717946, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12802.0717946, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12802.0717946, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12802.0717946, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12802.0717946, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12802.0717946, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12802.0717946, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15959.0269727, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15959.0269727, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15959.0269727, loss=squared_loss ..............
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:    6.4s
# [CV] ..... penalty=l1, alpha=15959.0269727, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15959.0269727, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15959.0269727, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15959.0269727, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15959.0269727, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15959.0269727, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15959.0269727, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=8936.8975238, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=8936.8975238, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8936.8975238, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=8936.8975238, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8936.8975238, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=8936.8975238, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8936.8975238, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=8936.8975238, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8936.8975238, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=8936.8975238, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=15227.5454291, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15227.5454291, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15227.5454291, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15227.5454291, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15227.5454291, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15227.5454291, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15227.5454291, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15227.5454291, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15227.5454291, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15227.5454291, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=11444.7739037, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=11444.7739037, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=11444.7739037, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=11444.7739037, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=11444.7739037, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=11444.7739037, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=11444.7739037, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=11444.7739037, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=11444.7739037, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=11444.7739037, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=8047.97532036, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8047.97532036, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8047.97532036, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8047.97532036, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8047.97532036, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8047.97532036, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8047.97532036, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8047.97532036, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=8047.97532036, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=8047.97532036, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7462.56917114, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7462.56917114, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7462.56917114, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7462.56917114, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7462.56917114, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7462.56917114, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7462.56917114, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7462.56917114, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7462.56917114, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7462.56917114, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=6451.53183907, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6451.53183907, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6451.53183907, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6451.53183907, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6451.53183907, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6451.53183907, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6451.53183907, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6451.53183907, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=6451.53183907, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6451.53183907, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=892.221352368, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=892.221352368, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=892.221352368, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=892.221352368, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=892.221352368, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=892.221352368, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=892.221352368, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=892.221352368, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=892.221352368, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=892.221352368, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=5282.61775995, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5282.61775995, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5282.61775995, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5282.61775995, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5282.61775995, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5282.61775995, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=5282.61775995, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5282.61775995, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5282.61775995, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5282.61775995, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13439.5852074, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13439.5852074, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13439.5852074, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13439.5852074, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13439.5852074, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13439.5852074, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13439.5852074, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13439.5852074, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=13439.5852074, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=13439.5852074, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18331.847596, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=18331.847596, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18331.847596, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=18331.847596, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18331.847596, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=18331.847596, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18331.847596, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=18331.847596, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18331.847596, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=18331.847596, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=19487.838983, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=19487.838983, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19487.838983, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=19487.838983, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19487.838983, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=19487.838983, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19487.838983, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=19487.838983, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19487.838983, loss=squared_loss ...............
# [CV] ...... penalty=l2, alpha=19487.838983, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=17928.6981066, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17928.6981066, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17928.6981066, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17928.6981066, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17928.6981066, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17928.6981066, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17928.6981066, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17928.6981066, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17928.6981066, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17928.6981066, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5208.94953611, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5208.94953611, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5208.94953611, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5208.94953611, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5208.94953611, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5208.94953611, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5208.94953611, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5208.94953611, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=5208.94953611, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=5208.94953611, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=19620.8837166, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=19620.8837166, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19620.8837166, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=19620.8837166, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19620.8837166, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=19620.8837166, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19620.8837166, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=19620.8837166, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=19620.8837166, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=19620.8837166, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=9699.37141462, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=9699.37141462, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9699.37141462, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=9699.37141462, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9699.37141462, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=9699.37141462, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9699.37141462, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=9699.37141462, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=9699.37141462, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=9699.37141462, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12102.4107999, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12102.4107999, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12102.4107999, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12102.4107999, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12102.4107999, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12102.4107999, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12102.4107999, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12102.4107999, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12102.4107999, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12102.4107999, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6148.45333579, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6148.45333579, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6148.45333579, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6148.45333579, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6148.45333579, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6148.45333579, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6148.45333579, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6148.45333579, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6148.45333579, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6148.45333579, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15568.2468712, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15568.2468712, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15568.2468712, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15568.2468712, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15568.2468712, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15568.2468712, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15568.2468712, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15568.2468712, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=15568.2468712, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=15568.2468712, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6036.62657069, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6036.62657069, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6036.62657069, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6036.62657069, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6036.62657069, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6036.62657069, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6036.62657069, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6036.62657069, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6036.62657069, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6036.62657069, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=10896.8150363, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10896.8150363, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10896.8150363, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10896.8150363, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10896.8150363, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10896.8150363, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10896.8150363, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10896.8150363, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10896.8150363, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10896.8150363, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11900.4335305, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11900.4335305, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11900.4335305, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11900.4335305, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11900.4335305, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11900.4335305, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11900.4335305, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11900.4335305, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11900.4335305, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11900.4335305, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11947.5003131, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11947.5003131, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11947.5003131, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11947.5003131, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11947.5003131, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11947.5003131, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11947.5003131, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11947.5003131, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=11947.5003131, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=11947.5003131, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=19960.4030723, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=19960.4030723, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=19960.4030723, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=19960.4030723, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=19960.4030723, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=19960.4030723, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=19960.4030723, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=19960.4030723, loss=squared_loss -   0.3s
# [CV] penalty=l1, alpha=19960.4030723, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=19960.4030723, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4002.64317285, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4002.64317285, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4002.64317285, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4002.64317285, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4002.64317285, loss=squared_loss ..............
# [Parallel(n_jobs=1)]: Done 161 tasks       | elapsed:   28.4s
# [CV] ..... penalty=l1, alpha=4002.64317285, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4002.64317285, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4002.64317285, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=4002.64317285, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=4002.64317285, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1157.09094288, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1157.09094288, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1157.09094288, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1157.09094288, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1157.09094288, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1157.09094288, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1157.09094288, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1157.09094288, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1157.09094288, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1157.09094288, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=9869.05235291, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=9869.05235291, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9869.05235291, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=9869.05235291, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9869.05235291, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=9869.05235291, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9869.05235291, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=9869.05235291, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=9869.05235291, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=9869.05235291, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=8327.16553646, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=8327.16553646, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=8327.16553646, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=8327.16553646, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=8327.16553646, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=8327.16553646, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=8327.16553646, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=8327.16553646, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=8327.16553646, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=8327.16553646, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=10130.9388284, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10130.9388284, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10130.9388284, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10130.9388284, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10130.9388284, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10130.9388284, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10130.9388284, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10130.9388284, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=10130.9388284, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=10130.9388284, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=12981.9893964, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12981.9893964, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12981.9893964, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12981.9893964, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12981.9893964, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12981.9893964, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12981.9893964, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12981.9893964, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12981.9893964, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12981.9893964, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=14840.7591282, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=14840.7591282, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=14840.7591282, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=14840.7591282, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=14840.7591282, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=14840.7591282, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=14840.7591282, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=14840.7591282, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=14840.7591282, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=14840.7591282, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=214.54055224, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=214.54055224, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=214.54055224, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=214.54055224, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=214.54055224, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=214.54055224, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=214.54055224, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=214.54055224, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=214.54055224, loss=squared_loss ...............
# [CV] ...... penalty=l1, alpha=214.54055224, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1719.10033506, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1719.10033506, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1719.10033506, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1719.10033506, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1719.10033506, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1719.10033506, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1719.10033506, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1719.10033506, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=1719.10033506, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=1719.10033506, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=6919.13057097, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6919.13057097, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6919.13057097, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6919.13057097, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6919.13057097, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6919.13057097, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6919.13057097, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6919.13057097, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6919.13057097, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6919.13057097, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=12139.6200712, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=12139.6200712, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=12139.6200712, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=12139.6200712, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=12139.6200712, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=12139.6200712, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=12139.6200712, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=12139.6200712, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=12139.6200712, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=12139.6200712, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=12452.9711977, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12452.9711977, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12452.9711977, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12452.9711977, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12452.9711977, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12452.9711977, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12452.9711977, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12452.9711977, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=12452.9711977, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=12452.9711977, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=17278.4265694, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=17278.4265694, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=17278.4265694, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=17278.4265694, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=17278.4265694, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=17278.4265694, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=17278.4265694, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=17278.4265694, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=17278.4265694, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=17278.4265694, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=17144.1591309, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17144.1591309, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17144.1591309, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17144.1591309, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17144.1591309, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17144.1591309, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17144.1591309, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17144.1591309, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=17144.1591309, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=17144.1591309, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18373.1399293, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18373.1399293, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18373.1399293, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18373.1399293, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18373.1399293, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18373.1399293, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18373.1399293, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18373.1399293, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=18373.1399293, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=18373.1399293, loss=squared_loss -   0.2s
# [CV] penalty=l2, alpha=6461.19990669, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6461.19990669, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6461.19990669, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6461.19990669, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6461.19990669, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6461.19990669, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6461.19990669, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6461.19990669, loss=squared_loss -   0.1s
# [CV] penalty=l2, alpha=6461.19990669, loss=squared_loss ..............
# [CV] ..... penalty=l2, alpha=6461.19990669, loss=squared_loss -   0.1s
# [CV] penalty=l1, alpha=6440.13915923, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6440.13915923, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6440.13915923, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6440.13915923, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6440.13915923, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6440.13915923, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6440.13915923, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6440.13915923, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=6440.13915923, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=6440.13915923, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7347.17073396, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7347.17073396, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7347.17073396, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7347.17073396, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7347.17073396, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7347.17073396, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7347.17073396, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7347.17073396, loss=squared_loss -   0.2s
# [CV] penalty=l1, alpha=7347.17073396, loss=squared_loss ..............
# [CV] ..... penalty=l1, alpha=7347.17073396, loss=squared_loss -   0.2s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:   43.6s finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=5, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False),
#           fit_params={}, iid=True, n_iter=50, n_jobs=1,
#           param_distributions={'penalty': ['l1', 'l2'], 'loss': ['squared_loss'], 'alpha': <scipy.stats._distn_infrastructure.rv_frozen object at 0x11a7460d0>},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           scoring=None, verbose=2)

# %%
print sgd_reg_rand_gs.best_params_
print sgd_reg_rand_gs.best_score_
sgd_rand_reg = sgd_reg_rand_gs.best_estimator_
# Out:
# {'penalty': 'l1', 'alpha': 15227.545429058833, 'loss': 'squared_loss'}
# 0.192974215378

# %%
sgd_reg_rand_gs_params = sgd_reg_rand_gs.get_params()

sgd_reg_rand_alphas = np.linspace(1., np.max(sgd_reg_rand_gs.best_params_['alpha']), 100.)
lcoefs_rand = lasso_coefs(Xn, y, sgd_reg_rand_alphas)

# %% [markdown]
# ---
#
# ### Visualize/examine the results from your RandomizedSearchCV results

# %%
# Plot the coefficients across alpha values:
fig, ax = plt.subplots(figsize=(11,7))

ax.plot(sgd_reg_rand_alphas, lcoefs, lw=1.5)

ax.axvline(sgd_reg_gs.best_params_['alpha'], lw=1.0, ls='dashed', label='best alpha')

ax.set_title('RandomizedSearchCV coef values across alphas')
ax.set_xlabel('alpha')
ax.set_ylabel('coef value')

plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ---
#
# ### SGDClassifier
#
# Using either GridSearchCV or RandomizedSearchCV, set up an X, y classification problem to look at. Depending on the data you loaded in, you may need to get new data.
#
# Find the optimal parameters.

# %%
ycls = prop_samp.property_class.map(lambda x: 1 if x == 'Z' else 0).values
print np.mean(ycls)

f = '~ '+' + '.join([c for c in prop_samp.columns if not c == 'value'])+' -1'
print f
Xcls = patsy.dmatrix(f, data=prop_samp, return_type='dataframe')

Xclsn = ss.fit_transform(Xcls)
print ycls.shape, Xcls.shape
# Out:
# 0.159466412072
# ~ baths + beds + lot_depth + basement_area + front_ft + owner_pct + rooms + property_class + neighborhood + tax_rate + volume + sqft + stories + year_recorded + year_built + zone -1
# (37707,) (37707, 168)

# %%
sgd_clf_params = {
    'loss':['log'],
    'penalty':['l1','l2'],
    'alpha':uniform
}

sgd_cls = SGDClassifier()
sgd_cls_gs = RandomizedSearchCV(sgd_cls, sgd_clf_params, cv=5, verbose=2, n_iter=100)

# %%
sgd_cls_gs.fit(Xcls, ycls)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] penalty=l1, alpha=4195.33650124, loss=log .......................
# [CV] .............. penalty=l1, alpha=4195.33650124, loss=log -   0.2s
# [CV] penalty=l1, alpha=4195.33650124, loss=log .......................
# [CV] .............. penalty=l1, alpha=4195.33650124, loss=log -   0.2s
# [CV] penalty=l1, alpha=4195.33650124, loss=log .......................
# [CV] .............. penalty=l1, alpha=4195.33650124, loss=log -   0.2s
# [CV] penalty=l1, alpha=4195.33650124, loss=log .......................
# [CV] .............. penalty=l1, alpha=4195.33650124, loss=log -   0.2s
# [CV] penalty=l1, alpha=4195.33650124, loss=log .......................
# [CV] .............. penalty=l1, alpha=4195.33650124, loss=log -   0.2s
# [CV] penalty=l1, alpha=4543.07445297, loss=log .......................
# [CV] .............. penalty=l1, alpha=4543.07445297, loss=log -   0.2s
# [CV] penalty=l1, alpha=4543.07445297, loss=log .......................
# [CV] .............. penalty=l1, alpha=4543.07445297, loss=log -   0.2s
# [CV] penalty=l1, alpha=4543.07445297, loss=log .......................
# [CV] .............. penalty=l1, alpha=4543.07445297, loss=log -   0.2s
# [CV] penalty=l1, alpha=4543.07445297, loss=log .......................
# [CV] .............. penalty=l1, alpha=4543.07445297, loss=log -   0.2s
# [CV] penalty=l1, alpha=4543.07445297, loss=log .......................
# [CV] .............. penalty=l1, alpha=4543.07445297, loss=log -   0.2s
# [CV] penalty=l2, alpha=5652.36054569, loss=log .......................
# [CV] .............. penalty=l2, alpha=5652.36054569, loss=log -   0.1s
# [CV] penalty=l2, alpha=5652.36054569, loss=log .......................
# [CV] .............. penalty=l2, alpha=5652.36054569, loss=log -   0.1s
# [CV] penalty=l2, alpha=5652.36054569, loss=log .......................
# [CV] .............. penalty=l2, alpha=5652.36054569, loss=log -   0.1s
# [CV] penalty=l2, alpha=5652.36054569, loss=log .......................
# [CV] .............. penalty=l2, alpha=5652.36054569, loss=log -   0.1s
# [CV] penalty=l2, alpha=5652.36054569, loss=log .......................
# [CV] .............. penalty=l2, alpha=5652.36054569, loss=log -   0.1s
# [CV] penalty=l2, alpha=2707.60640657, loss=log .......................
# [CV] .............. penalty=l2, alpha=2707.60640657, loss=log -   0.1s
# [CV] penalty=l2, alpha=2707.60640657, loss=log .......................
# [CV] .............. penalty=l2, alpha=2707.60640657, loss=log -   0.1s
# [CV] penalty=l2, alpha=2707.60640657, loss=log .......................
# [CV] .............. penalty=l2, alpha=2707.60640657, loss=log -   0.1s
# [CV] penalty=l2, alpha=2707.60640657, loss=log .......................
# [CV] .............. penalty=l2, alpha=2707.60640657, loss=log -   0.1s
# [CV] penalty=l2, alpha=2707.60640657, loss=log .......................
# [CV] .............. penalty=l2, alpha=2707.60640657, loss=log -   0.1s
# [CV] penalty=l2, alpha=16069.7277405, loss=log .......................
# [CV] .............. penalty=l2, alpha=16069.7277405, loss=log -   0.1s
# [CV] penalty=l2, alpha=16069.7277405, loss=log .......................
# [CV] .............. penalty=l2, alpha=16069.7277405, loss=log -   0.1s
# [CV] penalty=l2, alpha=16069.7277405, loss=log .......................
# [CV] .............. penalty=l2, alpha=16069.7277405, loss=log -   0.1s
# [CV] penalty=l2, alpha=16069.7277405, loss=log .......................
# [CV] .............. penalty=l2, alpha=16069.7277405, loss=log -   0.1s
# [CV] penalty=l2, alpha=16069.7277405, loss=log .......................
# [CV] .............. penalty=l2, alpha=16069.7277405, loss=log -   0.1s
# [CV] penalty=l2, alpha=7070.49204004, loss=log .......................
# [CV] .............. penalty=l2, alpha=7070.49204004, loss=log -   0.1s
# [CV] penalty=l2, alpha=7070.49204004, loss=log .......................
# [CV] .............. penalty=l2, alpha=7070.49204004, loss=log -   0.1s
# [CV] penalty=l2, alpha=7070.49204004, loss=log .......................
# [CV] .............. penalty=l2, alpha=7070.49204004, loss=log -   0.1s
# [CV] penalty=l2, alpha=7070.49204004, loss=log .......................
# [CV] .............. penalty=l2, alpha=7070.49204004, loss=log -   0.1s
# [CV] penalty=l2, alpha=7070.49204004, loss=log .......................
# [CV] .............. penalty=l2, alpha=7070.49204004, loss=log -   0.1s
# [CV] penalty=l1, alpha=5464.96126886, loss=log .......................
# [CV] .............. penalty=l1, alpha=5464.96126886, loss=log -   0.2s
# [CV] penalty=l1, alpha=5464.96126886, loss=log .......................
# [CV] .............. penalty=l1, alpha=5464.96126886, loss=log -   0.2s
# [CV] penalty=l1, alpha=5464.96126886, loss=log .......................
# [CV] .............. penalty=l1, alpha=5464.96126886, loss=log -   0.2s
# [CV] penalty=l1, alpha=5464.96126886, loss=log .......................
# [CV] .............. penalty=l1, alpha=5464.96126886, loss=log -   0.2s
# [CV] penalty=l1, alpha=5464.96126886, loss=log .......................
# [CV] .............. penalty=l1, alpha=5464.96126886, loss=log -   0.2s
# [CV] penalty=l1, alpha=17458.8428358, loss=log .......................
# [CV] .............. penalty=l1, alpha=17458.8428358, loss=log -   0.2s
# [CV] penalty=l1, alpha=17458.8428358, loss=log .......................
# [CV] .............. penalty=l1, alpha=17458.8428358, loss=log -   0.2s
# [CV] penalty=l1, alpha=17458.8428358, loss=log .......................
# [CV] .............. penalty=l1, alpha=17458.8428358, loss=log -   0.2s
# [CV] penalty=l1, alpha=17458.8428358, loss=log .......................
# [CV] .............. penalty=l1, alpha=17458.8428358, loss=log -   0.2s
# [CV] penalty=l1, alpha=17458.8428358, loss=log .......................
# [CV] .............. penalty=l1, alpha=17458.8428358, loss=log -   0.2s
# [CV] penalty=l1, alpha=11238.1392348, loss=log .......................
# [CV] .............. penalty=l1, alpha=11238.1392348, loss=log -   0.2s
# [CV] penalty=l1, alpha=11238.1392348, loss=log .......................
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:    6.8s
# [CV] .............. penalty=l1, alpha=11238.1392348, loss=log -   0.2s
# [CV] penalty=l1, alpha=11238.1392348, loss=log .......................
# [CV] .............. penalty=l1, alpha=11238.1392348, loss=log -   0.2s
# [CV] penalty=l1, alpha=11238.1392348, loss=log .......................
# [CV] .............. penalty=l1, alpha=11238.1392348, loss=log -   0.2s
# [CV] penalty=l1, alpha=11238.1392348, loss=log .......................
# [CV] .............. penalty=l1, alpha=11238.1392348, loss=log -   0.2s
# [CV] penalty=l2, alpha=19914.7542815, loss=log .......................
# [CV] .............. penalty=l2, alpha=19914.7542815, loss=log -   0.1s
# [CV] penalty=l2, alpha=19914.7542815, loss=log .......................
# [CV] .............. penalty=l2, alpha=19914.7542815, loss=log -   0.1s
# [CV] penalty=l2, alpha=19914.7542815, loss=log .......................
# [CV] .............. penalty=l2, alpha=19914.7542815, loss=log -   0.1s
# [CV] penalty=l2, alpha=19914.7542815, loss=log .......................
# [CV] .............. penalty=l2, alpha=19914.7542815, loss=log -   0.1s
# [CV] penalty=l2, alpha=19914.7542815, loss=log .......................
# [CV] .............. penalty=l2, alpha=19914.7542815, loss=log -   0.1s
# [CV] penalty=l1, alpha=14774.0231708, loss=log .......................
# [CV] .............. penalty=l1, alpha=14774.0231708, loss=log -   0.2s
# [CV] penalty=l1, alpha=14774.0231708, loss=log .......................
# [CV] .............. penalty=l1, alpha=14774.0231708, loss=log -   0.2s
# [CV] penalty=l1, alpha=14774.0231708, loss=log .......................
# [CV] .............. penalty=l1, alpha=14774.0231708, loss=log -   0.2s
# [CV] penalty=l1, alpha=14774.0231708, loss=log .......................
# [CV] .............. penalty=l1, alpha=14774.0231708, loss=log -   0.2s
# [CV] penalty=l1, alpha=14774.0231708, loss=log .......................
# [CV] .............. penalty=l1, alpha=14774.0231708, loss=log -   0.2s
# [CV] penalty=l2, alpha=11956.5511687, loss=log .......................
# [CV] .............. penalty=l2, alpha=11956.5511687, loss=log -   0.1s
# [CV] penalty=l2, alpha=11956.5511687, loss=log .......................
# [CV] .............. penalty=l2, alpha=11956.5511687, loss=log -   0.1s
# [CV] penalty=l2, alpha=11956.5511687, loss=log .......................
# [CV] .............. penalty=l2, alpha=11956.5511687, loss=log -   0.1s
# [CV] penalty=l2, alpha=11956.5511687, loss=log .......................
# [CV] .............. penalty=l2, alpha=11956.5511687, loss=log -   0.1s
# [CV] penalty=l2, alpha=11956.5511687, loss=log .......................
# [CV] .............. penalty=l2, alpha=11956.5511687, loss=log -   0.1s
# [CV] penalty=l1, alpha=2273.85308004, loss=log .......................
# [CV] .............. penalty=l1, alpha=2273.85308004, loss=log -   0.2s
# [CV] penalty=l1, alpha=2273.85308004, loss=log .......................
# [CV] .............. penalty=l1, alpha=2273.85308004, loss=log -   0.2s
# [CV] penalty=l1, alpha=2273.85308004, loss=log .......................
# [CV] .............. penalty=l1, alpha=2273.85308004, loss=log -   0.2s
# [CV] penalty=l1, alpha=2273.85308004, loss=log .......................
# [CV] .............. penalty=l1, alpha=2273.85308004, loss=log -   0.2s
# [CV] penalty=l1, alpha=2273.85308004, loss=log .......................
# [CV] .............. penalty=l1, alpha=2273.85308004, loss=log -   0.2s
# [CV] penalty=l1, alpha=13262.9928263, loss=log .......................
# [CV] .............. penalty=l1, alpha=13262.9928263, loss=log -   0.2s
# [CV] penalty=l1, alpha=13262.9928263, loss=log .......................
# [CV] .............. penalty=l1, alpha=13262.9928263, loss=log -   0.2s
# [CV] penalty=l1, alpha=13262.9928263, loss=log .......................
# [CV] .............. penalty=l1, alpha=13262.9928263, loss=log -   0.2s
# [CV] penalty=l1, alpha=13262.9928263, loss=log .......................
# [CV] .............. penalty=l1, alpha=13262.9928263, loss=log -   0.2s
# [CV] penalty=l1, alpha=13262.9928263, loss=log .......................
# [CV] .............. penalty=l1, alpha=13262.9928263, loss=log -   0.2s
# [CV] penalty=l2, alpha=299.065578315, loss=log .......................
# [CV] .............. penalty=l2, alpha=299.065578315, loss=log -   0.1s
# [CV] penalty=l2, alpha=299.065578315, loss=log .......................
# [CV] .............. penalty=l2, alpha=299.065578315, loss=log -   0.1s
# [CV] penalty=l2, alpha=299.065578315, loss=log .......................
# [CV] .............. penalty=l2, alpha=299.065578315, loss=log -   0.1s
# [CV] penalty=l2, alpha=299.065578315, loss=log .......................
# [CV] .............. penalty=l2, alpha=299.065578315, loss=log -   0.1s
# [CV] penalty=l2, alpha=299.065578315, loss=log .......................
# [CV] .............. penalty=l2, alpha=299.065578315, loss=log -   0.1s
# [CV] penalty=l2, alpha=3126.76686533, loss=log .......................
# [CV] .............. penalty=l2, alpha=3126.76686533, loss=log -   0.1s
# [CV] penalty=l2, alpha=3126.76686533, loss=log .......................
# [CV] .............. penalty=l2, alpha=3126.76686533, loss=log -   0.1s
# [CV] penalty=l2, alpha=3126.76686533, loss=log .......................
# [CV] .............. penalty=l2, alpha=3126.76686533, loss=log -   0.1s
# [CV] penalty=l2, alpha=3126.76686533, loss=log .......................
# [CV] .............. penalty=l2, alpha=3126.76686533, loss=log -   0.1s
# [CV] penalty=l2, alpha=3126.76686533, loss=log .......................
# [CV] .............. penalty=l2, alpha=3126.76686533, loss=log -   0.1s
# [CV] penalty=l1, alpha=13199.3434745, loss=log .......................
# [CV] .............. penalty=l1, alpha=13199.3434745, loss=log -   0.2s
# [CV] penalty=l1, alpha=13199.3434745, loss=log .......................
# [CV] .............. penalty=l1, alpha=13199.3434745, loss=log -   0.2s
# [CV] penalty=l1, alpha=13199.3434745, loss=log .......................
# [CV] .............. penalty=l1, alpha=13199.3434745, loss=log -   0.2s
# [CV] penalty=l1, alpha=13199.3434745, loss=log .......................
# [CV] .............. penalty=l1, alpha=13199.3434745, loss=log -   0.2s
# [CV] penalty=l1, alpha=13199.3434745, loss=log .......................
# [CV] .............. penalty=l1, alpha=13199.3434745, loss=log -   0.2s
# [CV] penalty=l2, alpha=14570.6552217, loss=log .......................
# [CV] .............. penalty=l2, alpha=14570.6552217, loss=log -   0.1s
# [CV] penalty=l2, alpha=14570.6552217, loss=log .......................
# [CV] .............. penalty=l2, alpha=14570.6552217, loss=log -   0.1s
# [CV] penalty=l2, alpha=14570.6552217, loss=log .......................
# [CV] .............. penalty=l2, alpha=14570.6552217, loss=log -   0.1s
# [CV] penalty=l2, alpha=14570.6552217, loss=log .......................
# [CV] .............. penalty=l2, alpha=14570.6552217, loss=log -   0.1s
# [CV] penalty=l2, alpha=14570.6552217, loss=log .......................
# [CV] .............. penalty=l2, alpha=14570.6552217, loss=log -   0.1s
# [CV] penalty=l2, alpha=6945.21168839, loss=log .......................
# [CV] .............. penalty=l2, alpha=6945.21168839, loss=log -   0.1s
# [CV] penalty=l2, alpha=6945.21168839, loss=log .......................
# [CV] .............. penalty=l2, alpha=6945.21168839, loss=log -   0.1s
# [CV] penalty=l2, alpha=6945.21168839, loss=log .......................
# [CV] .............. penalty=l2, alpha=6945.21168839, loss=log -   0.1s
# [CV] penalty=l2, alpha=6945.21168839, loss=log .......................
# [CV] .............. penalty=l2, alpha=6945.21168839, loss=log -   0.1s
# [CV] penalty=l2, alpha=6945.21168839, loss=log .......................
# [CV] .............. penalty=l2, alpha=6945.21168839, loss=log -   0.1s
# [CV] penalty=l2, alpha=12639.2878126, loss=log .......................
# [CV] .............. penalty=l2, alpha=12639.2878126, loss=log -   0.1s
# [CV] penalty=l2, alpha=12639.2878126, loss=log .......................
# [CV] .............. penalty=l2, alpha=12639.2878126, loss=log -   0.1s
# [CV] penalty=l2, alpha=12639.2878126, loss=log .......................
# [CV] .............. penalty=l2, alpha=12639.2878126, loss=log -   0.1s
# [CV] penalty=l2, alpha=12639.2878126, loss=log .......................
# [CV] .............. penalty=l2, alpha=12639.2878126, loss=log -   0.1s
# [CV] penalty=l2, alpha=12639.2878126, loss=log .......................
# [CV] .............. penalty=l2, alpha=12639.2878126, loss=log -   0.1s
# [CV] penalty=l1, alpha=11406.7298655, loss=log .......................
# [CV] .............. penalty=l1, alpha=11406.7298655, loss=log -   0.2s
# [CV] penalty=l1, alpha=11406.7298655, loss=log .......................
# [CV] .............. penalty=l1, alpha=11406.7298655, loss=log -   0.2s
# [CV] penalty=l1, alpha=11406.7298655, loss=log .......................
# [CV] .............. penalty=l1, alpha=11406.7298655, loss=log -   0.2s
# [CV] penalty=l1, alpha=11406.7298655, loss=log .......................
# [CV] .............. penalty=l1, alpha=11406.7298655, loss=log -   0.2s
# [CV] penalty=l1, alpha=11406.7298655, loss=log .......................
# [CV] .............. penalty=l1, alpha=11406.7298655, loss=log -   0.2s
# [CV] penalty=l2, alpha=10527.4827767, loss=log .......................
# [CV] .............. penalty=l2, alpha=10527.4827767, loss=log -   0.1s
# [CV] penalty=l2, alpha=10527.4827767, loss=log .......................
# [CV] .............. penalty=l2, alpha=10527.4827767, loss=log -   0.1s
# [CV] penalty=l2, alpha=10527.4827767, loss=log .......................
# [CV] .............. penalty=l2, alpha=10527.4827767, loss=log -   0.1s
# [CV] penalty=l2, alpha=10527.4827767, loss=log .......................
# [CV] .............. penalty=l2, alpha=10527.4827767, loss=log -   0.1s
# [CV] penalty=l2, alpha=10527.4827767, loss=log .......................
# [CV] .............. penalty=l2, alpha=10527.4827767, loss=log -   0.1s
# [CV] penalty=l2, alpha=15496.357948, loss=log ........................
# [CV] ............... penalty=l2, alpha=15496.357948, loss=log -   0.1s
# [CV] penalty=l2, alpha=15496.357948, loss=log ........................
# [CV] ............... penalty=l2, alpha=15496.357948, loss=log -   0.1s
# [CV] penalty=l2, alpha=15496.357948, loss=log ........................
# [CV] ............... penalty=l2, alpha=15496.357948, loss=log -   0.1s
# [CV] penalty=l2, alpha=15496.357948, loss=log ........................
# [CV] ............... penalty=l2, alpha=15496.357948, loss=log -   0.1s
# [CV] penalty=l2, alpha=15496.357948, loss=log ........................
# [CV] ............... penalty=l2, alpha=15496.357948, loss=log -   0.1s
# [CV] penalty=l2, alpha=9803.17654258, loss=log .......................
# [CV] .............. penalty=l2, alpha=9803.17654258, loss=log -   0.1s
# [CV] penalty=l2, alpha=9803.17654258, loss=log .......................
# [CV] .............. penalty=l2, alpha=9803.17654258, loss=log -   0.1s
# [CV] penalty=l2, alpha=9803.17654258, loss=log .......................
# [CV] .............. penalty=l2, alpha=9803.17654258, loss=log -   0.1s
# [CV] penalty=l2, alpha=9803.17654258, loss=log .......................
# [CV] .............. penalty=l2, alpha=9803.17654258, loss=log -   0.1s
# [CV] penalty=l2, alpha=9803.17654258, loss=log .......................
# [CV] .............. penalty=l2, alpha=9803.17654258, loss=log -   0.1s
# [CV] penalty=l1, alpha=13364.2701341, loss=log .......................
# [CV] .............. penalty=l1, alpha=13364.2701341, loss=log -   0.2s
# [CV] penalty=l1, alpha=13364.2701341, loss=log .......................
# [CV] .............. penalty=l1, alpha=13364.2701341, loss=log -   0.2s
# [CV] penalty=l1, alpha=13364.2701341, loss=log .......................
# [CV] .............. penalty=l1, alpha=13364.2701341, loss=log -   0.2s
# [CV] penalty=l1, alpha=13364.2701341, loss=log .......................
# [CV] .............. penalty=l1, alpha=13364.2701341, loss=log -   0.2s
# [CV] penalty=l1, alpha=13364.2701341, loss=log .......................
# [CV] .............. penalty=l1, alpha=13364.2701341, loss=log -   0.2s
# [CV] penalty=l2, alpha=9154.24073072, loss=log .......................
# [CV] .............. penalty=l2, alpha=9154.24073072, loss=log -   0.1s
# [CV] penalty=l2, alpha=9154.24073072, loss=log .......................
# [CV] .............. penalty=l2, alpha=9154.24073072, loss=log -   0.1s
# [CV] penalty=l2, alpha=9154.24073072, loss=log .......................
# [CV] .............. penalty=l2, alpha=9154.24073072, loss=log -   0.1s
# [CV] penalty=l2, alpha=9154.24073072, loss=log .......................
# [CV] .............. penalty=l2, alpha=9154.24073072, loss=log -   0.1s
# [CV] penalty=l2, alpha=9154.24073072, loss=log .......................
# [CV] .............. penalty=l2, alpha=9154.24073072, loss=log -   0.1s
# [CV] penalty=l1, alpha=1212.50131338, loss=log .......................
# [CV] .............. penalty=l1, alpha=1212.50131338, loss=log -   0.2s
# [CV] penalty=l1, alpha=1212.50131338, loss=log .......................
# [CV] .............. penalty=l1, alpha=1212.50131338, loss=log -   0.2s
# [CV] penalty=l1, alpha=1212.50131338, loss=log .......................
# [CV] .............. penalty=l1, alpha=1212.50131338, loss=log -   0.2s
# [CV] penalty=l1, alpha=1212.50131338, loss=log .......................
# [CV] .............. penalty=l1, alpha=1212.50131338, loss=log -   0.2s
# [CV] penalty=l1, alpha=1212.50131338, loss=log .......................
# [CV] .............. penalty=l1, alpha=1212.50131338, loss=log -   0.2s
# [CV] penalty=l2, alpha=16923.5744136, loss=log .......................
# [CV] .............. penalty=l2, alpha=16923.5744136, loss=log -   0.1s
# [CV] penalty=l2, alpha=16923.5744136, loss=log .......................
# [CV] .............. penalty=l2, alpha=16923.5744136, loss=log -   0.1s
# [CV] penalty=l2, alpha=16923.5744136, loss=log .......................
# [CV] .............. penalty=l2, alpha=16923.5744136, loss=log -   0.1s
# [CV] penalty=l2, alpha=16923.5744136, loss=log .......................
# [CV] .............. penalty=l2, alpha=16923.5744136, loss=log -   0.1s
# [CV] penalty=l2, alpha=16923.5744136, loss=log .......................
# [CV] .............. penalty=l2, alpha=16923.5744136, loss=log -   0.1s
# [CV] penalty=l1, alpha=604.71443483, loss=log ........................
# [CV] ............... penalty=l1, alpha=604.71443483, loss=log -   0.2s
# [CV] penalty=l1, alpha=604.71443483, loss=log ........................
# [CV] ............... penalty=l1, alpha=604.71443483, loss=log -   0.2s
# [CV] penalty=l1, alpha=604.71443483, loss=log ........................
# [CV] ............... penalty=l1, alpha=604.71443483, loss=log -   0.1s
# [CV] penalty=l1, alpha=604.71443483, loss=log ........................
# [CV] ............... penalty=l1, alpha=604.71443483, loss=log -   0.1s
# [CV] penalty=l1, alpha=604.71443483, loss=log ........................
# [CV] ............... penalty=l1, alpha=604.71443483, loss=log -   0.2s
# [CV] penalty=l2, alpha=11449.3497282, loss=log .......................
# [CV] .............. penalty=l2, alpha=11449.3497282, loss=log -   0.1s
# [CV] penalty=l2, alpha=11449.3497282, loss=log .......................
# [CV] .............. penalty=l2, alpha=11449.3497282, loss=log -   0.1s
# [CV] penalty=l2, alpha=11449.3497282, loss=log .......................
# [CV] .............. penalty=l2, alpha=11449.3497282, loss=log -   0.1s
# [CV] penalty=l2, alpha=11449.3497282, loss=log .......................
# [CV] .............. penalty=l2, alpha=11449.3497282, loss=log -   0.1s
# [CV] penalty=l2, alpha=11449.3497282, loss=log .......................
# [CV] .............. penalty=l2, alpha=11449.3497282, loss=log -   0.1s
# [CV] penalty=l1, alpha=9491.42695673, loss=log .......................
# [CV] .............. penalty=l1, alpha=9491.42695673, loss=log -   0.2s
# [CV] penalty=l1, alpha=9491.42695673, loss=log .......................
# [CV] .............. penalty=l1, alpha=9491.42695673, loss=log -   0.2s
# [CV] penalty=l1, alpha=9491.42695673, loss=log .......................
# [CV] .............. penalty=l1, alpha=9491.42695673, loss=log -   0.2s
# [CV] penalty=l1, alpha=9491.42695673, loss=log .......................
# [CV] .............. penalty=l1, alpha=9491.42695673, loss=log -   0.2s
# [CV] penalty=l1, alpha=9491.42695673, loss=log .......................
# [CV] .............. penalty=l1, alpha=9491.42695673, loss=log -   0.2s
# [CV] penalty=l1, alpha=11182.053338, loss=log ........................
# [CV] ............... penalty=l1, alpha=11182.053338, loss=log -   0.2s
# [CV] penalty=l1, alpha=11182.053338, loss=log ........................
# [CV] ............... penalty=l1, alpha=11182.053338, loss=log -   0.2s
# [CV] penalty=l1, alpha=11182.053338, loss=log ........................
# [CV] ............... penalty=l1, alpha=11182.053338, loss=log -   0.2s
# [CV] penalty=l1, alpha=11182.053338, loss=log ........................
# [CV] ............... penalty=l1, alpha=11182.053338, loss=log -   0.2s
# [CV] penalty=l1, alpha=11182.053338, loss=log ........................
# [CV] ............... penalty=l1, alpha=11182.053338, loss=log -   0.2s
# [CV] penalty=l1, alpha=18926.8081367, loss=log .......................
# [CV] .............. penalty=l1, alpha=18926.8081367, loss=log -   0.2s
# [CV] penalty=l1, alpha=18926.8081367, loss=log .......................
# [Parallel(n_jobs=1)]: Done 161 tasks       | elapsed:   26.7s
# [CV] .............. penalty=l1, alpha=18926.8081367, loss=log -   0.2s
# [CV] penalty=l1, alpha=18926.8081367, loss=log .......................
# [CV] .............. penalty=l1, alpha=18926.8081367, loss=log -   0.2s
# [CV] penalty=l1, alpha=18926.8081367, loss=log .......................
# [CV] .............. penalty=l1, alpha=18926.8081367, loss=log -   0.2s
# [CV] penalty=l1, alpha=18926.8081367, loss=log .......................
# [CV] .............. penalty=l1, alpha=18926.8081367, loss=log -   0.2s
# [CV] penalty=l1, alpha=18219.294445, loss=log ........................
# [CV] ............... penalty=l1, alpha=18219.294445, loss=log -   0.2s
# [CV] penalty=l1, alpha=18219.294445, loss=log ........................
# [CV] ............... penalty=l1, alpha=18219.294445, loss=log -   0.2s
# [CV] penalty=l1, alpha=18219.294445, loss=log ........................
# [CV] ............... penalty=l1, alpha=18219.294445, loss=log -   0.2s
# [CV] penalty=l1, alpha=18219.294445, loss=log ........................
# [CV] ............... penalty=l1, alpha=18219.294445, loss=log -   0.2s
# [CV] penalty=l1, alpha=18219.294445, loss=log ........................
# [CV] ............... penalty=l1, alpha=18219.294445, loss=log -   0.2s
# [CV] penalty=l2, alpha=17566.1301712, loss=log .......................
# [CV] .............. penalty=l2, alpha=17566.1301712, loss=log -   0.1s
# [CV] penalty=l2, alpha=17566.1301712, loss=log .......................
# [CV] .............. penalty=l2, alpha=17566.1301712, loss=log -   0.1s
# [CV] penalty=l2, alpha=17566.1301712, loss=log .......................
# [CV] .............. penalty=l2, alpha=17566.1301712, loss=log -   0.1s
# [CV] penalty=l2, alpha=17566.1301712, loss=log .......................
# [CV] .............. penalty=l2, alpha=17566.1301712, loss=log -   0.1s
# [CV] penalty=l2, alpha=17566.1301712, loss=log .......................
# [CV] .............. penalty=l2, alpha=17566.1301712, loss=log -   0.1s
# [CV] penalty=l2, alpha=13658.7894298, loss=log .......................
# [CV] .............. penalty=l2, alpha=13658.7894298, loss=log -   0.1s
# [CV] penalty=l2, alpha=13658.7894298, loss=log .......................
# [CV] .............. penalty=l2, alpha=13658.7894298, loss=log -   0.1s
# [CV] penalty=l2, alpha=13658.7894298, loss=log .......................
# [CV] .............. penalty=l2, alpha=13658.7894298, loss=log -   0.1s
# [CV] penalty=l2, alpha=13658.7894298, loss=log .......................
# [CV] .............. penalty=l2, alpha=13658.7894298, loss=log -   0.1s
# [CV] penalty=l2, alpha=13658.7894298, loss=log .......................
# [CV] .............. penalty=l2, alpha=13658.7894298, loss=log -   0.2s
# [CV] penalty=l1, alpha=7141.74717581, loss=log .......................
# [CV] .............. penalty=l1, alpha=7141.74717581, loss=log -   0.2s
# [CV] penalty=l1, alpha=7141.74717581, loss=log .......................
# [CV] .............. penalty=l1, alpha=7141.74717581, loss=log -   0.2s
# [CV] penalty=l1, alpha=7141.74717581, loss=log .......................
# [CV] .............. penalty=l1, alpha=7141.74717581, loss=log -   0.2s
# [CV] penalty=l1, alpha=7141.74717581, loss=log .......................
# [CV] .............. penalty=l1, alpha=7141.74717581, loss=log -   0.2s
# [CV] penalty=l1, alpha=7141.74717581, loss=log .......................
# [CV] .............. penalty=l1, alpha=7141.74717581, loss=log -   0.2s
# [CV] penalty=l2, alpha=12047.6781859, loss=log .......................
# [CV] .............. penalty=l2, alpha=12047.6781859, loss=log -   0.1s
# [CV] penalty=l2, alpha=12047.6781859, loss=log .......................
# [CV] .............. penalty=l2, alpha=12047.6781859, loss=log -   0.1s
# [CV] penalty=l2, alpha=12047.6781859, loss=log .......................
# [CV] .............. penalty=l2, alpha=12047.6781859, loss=log -   0.1s
# [CV] penalty=l2, alpha=12047.6781859, loss=log .......................
# [CV] .............. penalty=l2, alpha=12047.6781859, loss=log -   0.1s
# [CV] penalty=l2, alpha=12047.6781859, loss=log .......................
# [CV] .............. penalty=l2, alpha=12047.6781859, loss=log -   0.1s
# [CV] penalty=l1, alpha=1423.05700241, loss=log .......................
# [CV] .............. penalty=l1, alpha=1423.05700241, loss=log -   0.2s
# [CV] penalty=l1, alpha=1423.05700241, loss=log .......................
# [CV] .............. penalty=l1, alpha=1423.05700241, loss=log -   0.2s
# [CV] penalty=l1, alpha=1423.05700241, loss=log .......................
# [CV] .............. penalty=l1, alpha=1423.05700241, loss=log -   0.2s
# [CV] penalty=l1, alpha=1423.05700241, loss=log .......................
# [CV] .............. penalty=l1, alpha=1423.05700241, loss=log -   0.2s
# [CV] penalty=l1, alpha=1423.05700241, loss=log .......................
# [CV] .............. penalty=l1, alpha=1423.05700241, loss=log -   0.2s
# [CV] penalty=l1, alpha=17162.4342565, loss=log .......................
# [CV] .............. penalty=l1, alpha=17162.4342565, loss=log -   0.2s
# [CV] penalty=l1, alpha=17162.4342565, loss=log .......................
# [CV] .............. penalty=l1, alpha=17162.4342565, loss=log -   0.2s
# [CV] penalty=l1, alpha=17162.4342565, loss=log .......................
# [CV] .............. penalty=l1, alpha=17162.4342565, loss=log -   0.2s
# [CV] penalty=l1, alpha=17162.4342565, loss=log .......................
# [CV] .............. penalty=l1, alpha=17162.4342565, loss=log -   0.2s
# [CV] penalty=l1, alpha=17162.4342565, loss=log .......................
# [CV] .............. penalty=l1, alpha=17162.4342565, loss=log -   0.2s
# [CV] penalty=l1, alpha=4369.65792586, loss=log .......................
# [CV] .............. penalty=l1, alpha=4369.65792586, loss=log -   0.2s
# [CV] penalty=l1, alpha=4369.65792586, loss=log .......................
# [CV] .............. penalty=l1, alpha=4369.65792586, loss=log -   0.2s
# [CV] penalty=l1, alpha=4369.65792586, loss=log .......................
# [CV] .............. penalty=l1, alpha=4369.65792586, loss=log -   0.2s
# [CV] penalty=l1, alpha=4369.65792586, loss=log .......................
# [CV] .............. penalty=l1, alpha=4369.65792586, loss=log -   0.2s
# [CV] penalty=l1, alpha=4369.65792586, loss=log .......................
# [CV] .............. penalty=l1, alpha=4369.65792586, loss=log -   0.2s
# [CV] penalty=l1, alpha=13128.9947786, loss=log .......................
# [CV] .............. penalty=l1, alpha=13128.9947786, loss=log -   0.2s
# [CV] penalty=l1, alpha=13128.9947786, loss=log .......................
# [CV] .............. penalty=l1, alpha=13128.9947786, loss=log -   0.2s
# [CV] penalty=l1, alpha=13128.9947786, loss=log .......................
# [CV] .............. penalty=l1, alpha=13128.9947786, loss=log -   0.2s
# [CV] penalty=l1, alpha=13128.9947786, loss=log .......................
# [CV] .............. penalty=l1, alpha=13128.9947786, loss=log -   0.2s
# [CV] penalty=l1, alpha=13128.9947786, loss=log .......................
# [CV] .............. penalty=l1, alpha=13128.9947786, loss=log -   0.2s
# [CV] penalty=l1, alpha=9063.69417376, loss=log .......................
# [CV] .............. penalty=l1, alpha=9063.69417376, loss=log -   0.2s
# [CV] penalty=l1, alpha=9063.69417376, loss=log .......................
# [CV] .............. penalty=l1, alpha=9063.69417376, loss=log -   0.2s
# [CV] penalty=l1, alpha=9063.69417376, loss=log .......................
# [CV] .............. penalty=l1, alpha=9063.69417376, loss=log -   0.2s
# [CV] penalty=l1, alpha=9063.69417376, loss=log .......................
# [CV] .............. penalty=l1, alpha=9063.69417376, loss=log -   0.2s
# [CV] penalty=l1, alpha=9063.69417376, loss=log .......................
# [CV] .............. penalty=l1, alpha=9063.69417376, loss=log -   0.2s
# [CV] penalty=l2, alpha=8029.45822424, loss=log .......................
# [CV] .............. penalty=l2, alpha=8029.45822424, loss=log -   0.1s
# [CV] penalty=l2, alpha=8029.45822424, loss=log .......................
# [CV] .............. penalty=l2, alpha=8029.45822424, loss=log -   0.1s
# [CV] penalty=l2, alpha=8029.45822424, loss=log .......................
# [CV] .............. penalty=l2, alpha=8029.45822424, loss=log -   0.2s
# [CV] penalty=l2, alpha=8029.45822424, loss=log .......................
# [CV] .............. penalty=l2, alpha=8029.45822424, loss=log -   0.2s
# [CV] penalty=l2, alpha=8029.45822424, loss=log .......................
# [CV] .............. penalty=l2, alpha=8029.45822424, loss=log -   0.1s
# [CV] penalty=l1, alpha=14882.5139313, loss=log .......................
# [CV] .............. penalty=l1, alpha=14882.5139313, loss=log -   0.2s
# [CV] penalty=l1, alpha=14882.5139313, loss=log .......................
# [CV] .............. penalty=l1, alpha=14882.5139313, loss=log -   0.2s
# [CV] penalty=l1, alpha=14882.5139313, loss=log .......................
# [CV] .............. penalty=l1, alpha=14882.5139313, loss=log -   0.2s
# [CV] penalty=l1, alpha=14882.5139313, loss=log .......................
# [CV] .............. penalty=l1, alpha=14882.5139313, loss=log -   0.2s
# [CV] penalty=l1, alpha=14882.5139313, loss=log .......................
# [CV] .............. penalty=l1, alpha=14882.5139313, loss=log -   0.2s
# [CV] penalty=l1, alpha=7705.32975226, loss=log .......................
# [CV] .............. penalty=l1, alpha=7705.32975226, loss=log -   0.2s
# [CV] penalty=l1, alpha=7705.32975226, loss=log .......................
# [CV] .............. penalty=l1, alpha=7705.32975226, loss=log -   0.2s
# [CV] penalty=l1, alpha=7705.32975226, loss=log .......................
# [CV] .............. penalty=l1, alpha=7705.32975226, loss=log -   0.2s
# [CV] penalty=l1, alpha=7705.32975226, loss=log .......................
# [CV] .............. penalty=l1, alpha=7705.32975226, loss=log -   0.2s
# [CV] penalty=l1, alpha=7705.32975226, loss=log .......................
# [CV] .............. penalty=l1, alpha=7705.32975226, loss=log -   0.2s
# [CV] penalty=l1, alpha=10490.2196695, loss=log .......................
# [CV] .............. penalty=l1, alpha=10490.2196695, loss=log -   0.2s
# [CV] penalty=l1, alpha=10490.2196695, loss=log .......................
# [CV] .............. penalty=l1, alpha=10490.2196695, loss=log -   0.2s
# [CV] penalty=l1, alpha=10490.2196695, loss=log .......................
# [CV] .............. penalty=l1, alpha=10490.2196695, loss=log -   0.2s
# [CV] penalty=l1, alpha=10490.2196695, loss=log .......................
# [CV] .............. penalty=l1, alpha=10490.2196695, loss=log -   0.2s
# [CV] penalty=l1, alpha=10490.2196695, loss=log .......................
# [CV] .............. penalty=l1, alpha=10490.2196695, loss=log -   0.2s
# [CV] penalty=l1, alpha=15626.1112457, loss=log .......................
# [CV] .............. penalty=l1, alpha=15626.1112457, loss=log -   0.2s
# [CV] penalty=l1, alpha=15626.1112457, loss=log .......................
# [CV] .............. penalty=l1, alpha=15626.1112457, loss=log -   0.2s
# [CV] penalty=l1, alpha=15626.1112457, loss=log .......................
# [CV] .............. penalty=l1, alpha=15626.1112457, loss=log -   0.2s
# [CV] penalty=l1, alpha=15626.1112457, loss=log .......................
# [CV] .............. penalty=l1, alpha=15626.1112457, loss=log -   0.2s
# [CV] penalty=l1, alpha=15626.1112457, loss=log .......................
# [CV] .............. penalty=l1, alpha=15626.1112457, loss=log -   0.2s
# [CV] penalty=l1, alpha=13894.4516468, loss=log .......................
# [CV] .............. penalty=l1, alpha=13894.4516468, loss=log -   0.2s
# [CV] penalty=l1, alpha=13894.4516468, loss=log .......................
# [CV] .............. penalty=l1, alpha=13894.4516468, loss=log -   0.2s
# [CV] penalty=l1, alpha=13894.4516468, loss=log .......................
# [CV] .............. penalty=l1, alpha=13894.4516468, loss=log -   0.2s
# [CV] penalty=l1, alpha=13894.4516468, loss=log .......................
# [CV] .............. penalty=l1, alpha=13894.4516468, loss=log -   0.2s
# [CV] penalty=l1, alpha=13894.4516468, loss=log .......................
# [CV] .............. penalty=l1, alpha=13894.4516468, loss=log -   0.2s
# [CV] penalty=l1, alpha=15216.8697121, loss=log .......................
# [CV] .............. penalty=l1, alpha=15216.8697121, loss=log -   0.2s
# [CV] penalty=l1, alpha=15216.8697121, loss=log .......................
# [CV] .............. penalty=l1, alpha=15216.8697121, loss=log -   0.2s
# [CV] penalty=l1, alpha=15216.8697121, loss=log .......................
# [CV] .............. penalty=l1, alpha=15216.8697121, loss=log -   0.2s
# [CV] penalty=l1, alpha=15216.8697121, loss=log .......................
# [CV] .............. penalty=l1, alpha=15216.8697121, loss=log -   0.2s
# [CV] penalty=l1, alpha=15216.8697121, loss=log .......................
# [CV] .............. penalty=l1, alpha=15216.8697121, loss=log -   0.2s
# [CV] penalty=l1, alpha=2302.95933598, loss=log .......................
# [CV] .............. penalty=l1, alpha=2302.95933598, loss=log -   0.2s
# [CV] penalty=l1, alpha=2302.95933598, loss=log .......................
# [CV] .............. penalty=l1, alpha=2302.95933598, loss=log -   0.2s
# [CV] penalty=l1, alpha=2302.95933598, loss=log .......................
# [CV] .............. penalty=l1, alpha=2302.95933598, loss=log -   0.2s
# [CV] penalty=l1, alpha=2302.95933598, loss=log .......................
# [CV] .............. penalty=l1, alpha=2302.95933598, loss=log -   0.2s
# [CV] penalty=l1, alpha=2302.95933598, loss=log .......................
# [CV] .............. penalty=l1, alpha=2302.95933598, loss=log -   0.2s
# [CV] penalty=l1, alpha=15117.8944148, loss=log .......................
# [CV] .............. penalty=l1, alpha=15117.8944148, loss=log -   0.2s
# [CV] penalty=l1, alpha=15117.8944148, loss=log .......................
# [CV] .............. penalty=l1, alpha=15117.8944148, loss=log -   0.2s
# [CV] penalty=l1, alpha=15117.8944148, loss=log .......................
# [CV] .............. penalty=l1, alpha=15117.8944148, loss=log -   0.2s
# [CV] penalty=l1, alpha=15117.8944148, loss=log .......................
# [CV] .............. penalty=l1, alpha=15117.8944148, loss=log -   0.2s
# [CV] penalty=l1, alpha=15117.8944148, loss=log .......................
# [CV] .............. penalty=l1, alpha=15117.8944148, loss=log -   0.2s
# [CV] penalty=l1, alpha=533.074547083, loss=log .......................
# [CV] .............. penalty=l1, alpha=533.074547083, loss=log -   0.1s
# [CV] penalty=l1, alpha=533.074547083, loss=log .......................
# [CV] .............. penalty=l1, alpha=533.074547083, loss=log -   0.1s
# [CV] penalty=l1, alpha=533.074547083, loss=log .......................
# [CV] .............. penalty=l1, alpha=533.074547083, loss=log -   0.1s
# [CV] penalty=l1, alpha=533.074547083, loss=log .......................
# [CV] .............. penalty=l1, alpha=533.074547083, loss=log -   0.2s
# [CV] penalty=l1, alpha=533.074547083, loss=log .......................
# [CV] .............. penalty=l1, alpha=533.074547083, loss=log -   0.2s
# [CV] penalty=l1, alpha=3478.7363874, loss=log ........................
# [CV] ............... penalty=l1, alpha=3478.7363874, loss=log -   0.2s
# [CV] penalty=l1, alpha=3478.7363874, loss=log ........................
# [CV] ............... penalty=l1, alpha=3478.7363874, loss=log -   0.2s
# [CV] penalty=l1, alpha=3478.7363874, loss=log ........................
# [CV] ............... penalty=l1, alpha=3478.7363874, loss=log -   0.2s
# [CV] penalty=l1, alpha=3478.7363874, loss=log ........................
# [CV] ............... penalty=l1, alpha=3478.7363874, loss=log -   0.2s
# [CV] penalty=l1, alpha=3478.7363874, loss=log ........................
# [CV] ............... penalty=l1, alpha=3478.7363874, loss=log -   0.2s
# [CV] penalty=l2, alpha=1491.5605721, loss=log ........................
# [CV] ............... penalty=l2, alpha=1491.5605721, loss=log -   0.2s
# [CV] penalty=l2, alpha=1491.5605721, loss=log ........................
# [CV] ............... penalty=l2, alpha=1491.5605721, loss=log -   0.1s
# [CV] penalty=l2, alpha=1491.5605721, loss=log ........................
# [CV] ............... penalty=l2, alpha=1491.5605721, loss=log -   0.1s
# [CV] penalty=l2, alpha=1491.5605721, loss=log ........................
# [CV] ............... penalty=l2, alpha=1491.5605721, loss=log -   0.1s
# [CV] penalty=l2, alpha=1491.5605721, loss=log ........................
# [CV] ............... penalty=l2, alpha=1491.5605721, loss=log -   0.1s
# [CV] penalty=l1, alpha=1614.52319641, loss=log .......................
# [CV] .............. penalty=l1, alpha=1614.52319641, loss=log -   0.2s
# [CV] penalty=l1, alpha=1614.52319641, loss=log .......................
# [CV] .............. penalty=l1, alpha=1614.52319641, loss=log -   0.2s
# [CV] penalty=l1, alpha=1614.52319641, loss=log .......................
# [CV] .............. penalty=l1, alpha=1614.52319641, loss=log -   0.2s
# [CV] penalty=l1, alpha=1614.52319641, loss=log .......................
# [CV] .............. penalty=l1, alpha=1614.52319641, loss=log -   0.2s
# [CV] penalty=l1, alpha=1614.52319641, loss=log .......................
# [CV] .............. penalty=l1, alpha=1614.52319641, loss=log -   0.2s
# [CV] penalty=l2, alpha=6440.71332402, loss=log .......................
# [CV] .............. penalty=l2, alpha=6440.71332402, loss=log -   0.1s
# [CV] penalty=l2, alpha=6440.71332402, loss=log .......................
# [CV] .............. penalty=l2, alpha=6440.71332402, loss=log -   0.1s
# [CV] penalty=l2, alpha=6440.71332402, loss=log .......................
# [CV] .............. penalty=l2, alpha=6440.71332402, loss=log -   0.1s
# [CV] penalty=l2, alpha=6440.71332402, loss=log .......................
# [CV] .............. penalty=l2, alpha=6440.71332402, loss=log -   0.1s
# [CV] penalty=l2, alpha=6440.71332402, loss=log .......................
# [CV] .............. penalty=l2, alpha=6440.71332402, loss=log -   0.1s
# [CV] penalty=l2, alpha=14279.2914797, loss=log .......................
# [CV] .............. penalty=l2, alpha=14279.2914797, loss=log -   0.1s
# [CV] penalty=l2, alpha=14279.2914797, loss=log .......................
# [CV] .............. penalty=l2, alpha=14279.2914797, loss=log -   0.1s
# [CV] penalty=l2, alpha=14279.2914797, loss=log .......................
# [CV] .............. penalty=l2, alpha=14279.2914797, loss=log -   0.1s
# [CV] penalty=l2, alpha=14279.2914797, loss=log .......................
# [CV] .............. penalty=l2, alpha=14279.2914797, loss=log -   0.1s
# [CV] penalty=l2, alpha=14279.2914797, loss=log .......................
# [CV] .............. penalty=l2, alpha=14279.2914797, loss=log -   0.1s
# [CV] penalty=l1, alpha=3536.2215445, loss=log ........................
# [CV] ............... penalty=l1, alpha=3536.2215445, loss=log -   0.2s
# [CV] penalty=l1, alpha=3536.2215445, loss=log ........................
# [CV] ............... penalty=l1, alpha=3536.2215445, loss=log -   0.2s
# [CV] penalty=l1, alpha=3536.2215445, loss=log ........................
# [CV] ............... penalty=l1, alpha=3536.2215445, loss=log -   0.2s
# [CV] penalty=l1, alpha=3536.2215445, loss=log ........................
# [CV] ............... penalty=l1, alpha=3536.2215445, loss=log -   0.2s
# [CV] penalty=l1, alpha=3536.2215445, loss=log ........................
# [CV] ............... penalty=l1, alpha=3536.2215445, loss=log -   0.3s
# [CV] penalty=l2, alpha=7343.34885455, loss=log .......................
# [CV] .............. penalty=l2, alpha=7343.34885455, loss=log -   0.2s
# [CV] penalty=l2, alpha=7343.34885455, loss=log .......................
# [CV] .............. penalty=l2, alpha=7343.34885455, loss=log -   0.2s
# [CV] penalty=l2, alpha=7343.34885455, loss=log .......................
# [CV] .............. penalty=l2, alpha=7343.34885455, loss=log -   0.2s
# [CV] penalty=l2, alpha=7343.34885455, loss=log .......................
# [CV] .............. penalty=l2, alpha=7343.34885455, loss=log -   0.2s
# [CV] penalty=l2, alpha=7343.34885455, loss=log .......................
# [CV] .............. penalty=l2, alpha=7343.34885455, loss=log -   0.2s
# [CV] penalty=l2, alpha=12812.2846468, loss=log .......................
# [CV] .............. penalty=l2, alpha=12812.2846468, loss=log -   0.2s
# [CV] penalty=l2, alpha=12812.2846468, loss=log .......................
# [CV] .............. penalty=l2, alpha=12812.2846468, loss=log -   0.2s
# [CV] penalty=l2, alpha=12812.2846468, loss=log .......................
# [CV] .............. penalty=l2, alpha=12812.2846468, loss=log -   0.1s
# [CV] penalty=l2, alpha=12812.2846468, loss=log .......................
# [CV] .............. penalty=l2, alpha=12812.2846468, loss=log -   0.1s
# [CV] penalty=l2, alpha=12812.2846468, loss=log .......................
# [CV] .............. penalty=l2, alpha=12812.2846468, loss=log -   0.2s
# [CV] penalty=l1, alpha=16784.450533, loss=log ........................
# [CV] ............... penalty=l1, alpha=16784.450533, loss=log -   0.3s
# [CV] penalty=l1, alpha=16784.450533, loss=log ........................
# [CV] ............... penalty=l1, alpha=16784.450533, loss=log -   0.3s
# [CV] penalty=l1, alpha=16784.450533, loss=log ........................
# [CV] ............... penalty=l1, alpha=16784.450533, loss=log -   0.2s
# [CV] penalty=l1, alpha=16784.450533, loss=log ........................
# [CV] ............... penalty=l1, alpha=16784.450533, loss=log -   0.3s
# [CV] penalty=l1, alpha=16784.450533, loss=log ........................
# [CV] ............... penalty=l1, alpha=16784.450533, loss=log -   0.3s
# [CV] penalty=l1, alpha=11722.2088537, loss=log .......................
# [CV] .............. penalty=l1, alpha=11722.2088537, loss=log -   0.3s
# [CV] penalty=l1, alpha=11722.2088537, loss=log .......................
# [CV] .............. penalty=l1, alpha=11722.2088537, loss=log -   0.3s
# [CV] penalty=l1, alpha=11722.2088537, loss=log .......................
# [CV] .............. penalty=l1, alpha=11722.2088537, loss=log -   0.4s
# [CV] penalty=l1, alpha=11722.2088537, loss=log .......................
# [CV] .............. penalty=l1, alpha=11722.2088537, loss=log -   0.3s
# [CV] penalty=l1, alpha=11722.2088537, loss=log .......................
# [CV] .............. penalty=l1, alpha=11722.2088537, loss=log -   0.4s
# [CV] penalty=l1, alpha=14696.1952896, loss=log .......................
# [CV] .............. penalty=l1, alpha=14696.1952896, loss=log -   0.3s
# [CV] penalty=l1, alpha=14696.1952896, loss=log .......................
# [CV] .............. penalty=l1, alpha=14696.1952896, loss=log -   0.3s
# [CV] penalty=l1, alpha=14696.1952896, loss=log .......................
# [CV] .............. penalty=l1, alpha=14696.1952896, loss=log -   0.2s
# [CV] penalty=l1, alpha=14696.1952896, loss=log .......................
# [CV] .............. penalty=l1, alpha=14696.1952896, loss=log -   0.3s
# [CV] penalty=l1, alpha=14696.1952896, loss=log .......................
# [CV] .............. penalty=l1, alpha=14696.1952896, loss=log -   0.3s
# [CV] penalty=l1, alpha=14277.480015, loss=log ........................
# [CV] ............... penalty=l1, alpha=14277.480015, loss=log -   0.3s
# [CV] penalty=l1, alpha=14277.480015, loss=log ........................
# [CV] ............... penalty=l1, alpha=14277.480015, loss=log -   0.3s
# [CV] penalty=l1, alpha=14277.480015, loss=log ........................
# [CV] ............... penalty=l1, alpha=14277.480015, loss=log -   0.3s
# [CV] penalty=l1, alpha=14277.480015, loss=log ........................
# [CV] ............... penalty=l1, alpha=14277.480015, loss=log -   0.3s
# [CV] penalty=l1, alpha=14277.480015, loss=log ........................
# [CV] ............... penalty=l1, alpha=14277.480015, loss=log -   0.3s
# [CV] penalty=l2, alpha=8572.38265856, loss=log .......................
# [CV] .............. penalty=l2, alpha=8572.38265856, loss=log -   0.2s
# [CV] penalty=l2, alpha=8572.38265856, loss=log .......................
# [CV] .............. penalty=l2, alpha=8572.38265856, loss=log -   0.2s
# [CV] penalty=l2, alpha=8572.38265856, loss=log .......................
# [CV] .............. penalty=l2, alpha=8572.38265856, loss=log -   0.2s
# [CV] penalty=l2, alpha=8572.38265856, loss=log .......................
# [CV] .............. penalty=l2, alpha=8572.38265856, loss=log -   0.2s
# [CV] penalty=l2, alpha=8572.38265856, loss=log .......................
# [CV] .............. penalty=l2, alpha=8572.38265856, loss=log -   0.1s
# [CV] penalty=l2, alpha=11459.566906, loss=log ........................
# [CV] ............... penalty=l2, alpha=11459.566906, loss=log -   0.1s
# [CV] penalty=l2, alpha=11459.566906, loss=log ........................
# [CV] ............... penalty=l2, alpha=11459.566906, loss=log -   0.1s
# [CV] penalty=l2, alpha=11459.566906, loss=log ........................
# [CV] ............... penalty=l2, alpha=11459.566906, loss=log -   0.2s
# [CV] penalty=l2, alpha=11459.566906, loss=log ........................
# [CV] ............... penalty=l2, alpha=11459.566906, loss=log -   0.2s
# [CV] penalty=l2, alpha=11459.566906, loss=log ........................
# [CV] ............... penalty=l2, alpha=11459.566906, loss=log -   0.2s
# [CV] penalty=l1, alpha=11846.1582258, loss=log .......................
# [CV] .............. penalty=l1, alpha=11846.1582258, loss=log -   0.2s
# [CV] penalty=l1, alpha=11846.1582258, loss=log .......................
# ...
# [CV] penalty=l2, alpha=6316.87179798, loss=log .......................
# [CV] .............. penalty=l2, alpha=6316.87179798, loss=log -   0.2s
# [CV] penalty=l2, alpha=6316.87179798, loss=log .......................
# [CV] .............. penalty=l2, alpha=6316.87179798, loss=log -   0.1s
# [CV] penalty=l2, alpha=7875.75637229, loss=log .......................
# [CV] .............. penalty=l2, alpha=7875.75637229, loss=log -   0.1s
# [CV] penalty=l2, alpha=7875.75637229, loss=log .......................
# [CV] .............. penalty=l2, alpha=7875.75637229, loss=log -   0.1s
# [CV] penalty=l2, alpha=7875.75637229, loss=log .......................
# [CV] .............. penalty=l2, alpha=7875.75637229, loss=log -   0.1s
# [CV] penalty=l2, alpha=7875.75637229, loss=log .......................
# [CV] .............. penalty=l2, alpha=7875.75637229, loss=log -   0.1s
# [CV] penalty=l2, alpha=7875.75637229, loss=log .......................
# [CV] .............. penalty=l2, alpha=7875.75637229, loss=log -   0.1s
# [CV] penalty=l1, alpha=12843.2846955, loss=log .......................
# [CV] .............. penalty=l1, alpha=12843.2846955, loss=log -   0.2s
# [CV] penalty=l1, alpha=12843.2846955, loss=log .......................
# [CV] .............. penalty=l1, alpha=12843.2846955, loss=log -   0.2s
# [CV] penalty=l1, alpha=12843.2846955, loss=log .......................
# [CV] .............. penalty=l1, alpha=12843.2846955, loss=log -   0.2s
# [CV] penalty=l1, alpha=12843.2846955, loss=log .......................
# [CV] .............. penalty=l1, alpha=12843.2846955, loss=log -   0.2s
# [CV] penalty=l1, alpha=12843.2846955, loss=log .......................
# [CV] .............. penalty=l1, alpha=12843.2846955, loss=log -   0.2s
# [CV] penalty=l2, alpha=15943.6374236, loss=log .......................
# [CV] .............. penalty=l2, alpha=15943.6374236, loss=log -   0.1s
# [CV] penalty=l2, alpha=15943.6374236, loss=log .......................
# [CV] .............. penalty=l2, alpha=15943.6374236, loss=log -   0.1s
# [CV] penalty=l2, alpha=15943.6374236, loss=log .......................
# [CV] .............. penalty=l2, alpha=15943.6374236, loss=log -   0.1s
# [CV] penalty=l2, alpha=15943.6374236, loss=log .......................
# [CV] .............. penalty=l2, alpha=15943.6374236, loss=log -   0.1s
# [CV] penalty=l2, alpha=15943.6374236, loss=log .......................
# [CV] .............. penalty=l2, alpha=15943.6374236, loss=log -   0.1s
# [CV] penalty=l2, alpha=17010.2273466, loss=log .......................
# [CV] .............. penalty=l2, alpha=17010.2273466, loss=log -   0.1s
# [CV] penalty=l2, alpha=17010.2273466, loss=log .......................
# [CV] .............. penalty=l2, alpha=17010.2273466, loss=log -   0.1s
# [CV] penalty=l2, alpha=17010.2273466, loss=log .......................
# [CV] .............. penalty=l2, alpha=17010.2273466, loss=log -   0.1s
# [CV] penalty=l2, alpha=17010.2273466, loss=log .......................
# [CV] .............. penalty=l2, alpha=17010.2273466, loss=log -   0.1s
# [CV] penalty=l2, alpha=17010.2273466, loss=log .......................
# [CV] .............. penalty=l2, alpha=17010.2273466, loss=log -   0.1s
# [CV] penalty=l2, alpha=18468.2427064, loss=log .......................
# [CV] .............. penalty=l2, alpha=18468.2427064, loss=log -   0.1s
# [CV] penalty=l2, alpha=18468.2427064, loss=log .......................
# [CV] .............. penalty=l2, alpha=18468.2427064, loss=log -   0.1s
# [CV] penalty=l2, alpha=18468.2427064, loss=log .......................
# [CV] .............. penalty=l2, alpha=18468.2427064, loss=log -   0.1s
# [CV] penalty=l2, alpha=18468.2427064, loss=log .......................
# [CV] .............. penalty=l2, alpha=18468.2427064, loss=log -   0.1s
# [CV] penalty=l2, alpha=18468.2427064, loss=log .......................
# [CV] .............. penalty=l2, alpha=18468.2427064, loss=log -   0.1s
# [CV] penalty=l2, alpha=13449.0869312, loss=log .......................
# [CV] .............. penalty=l2, alpha=13449.0869312, loss=log -   0.1s
# [CV] penalty=l2, alpha=13449.0869312, loss=log .......................
# [CV] .............. penalty=l2, alpha=13449.0869312, loss=log -   0.1s
# [CV] penalty=l2, alpha=13449.0869312, loss=log .......................
# [CV] .............. penalty=l2, alpha=13449.0869312, loss=log -   0.1s
# [CV] penalty=l2, alpha=13449.0869312, loss=log .......................
# [CV] .............. penalty=l2, alpha=13449.0869312, loss=log -   0.1s
# [CV] penalty=l2, alpha=13449.0869312, loss=log .......................
# [CV] .............. penalty=l2, alpha=13449.0869312, loss=log -   0.1s
# [CV] penalty=l1, alpha=4767.77115035, loss=log .......................
# [CV] .............. penalty=l1, alpha=4767.77115035, loss=log -   0.2s
# [CV] penalty=l1, alpha=4767.77115035, loss=log .......................
# [CV] .............. penalty=l1, alpha=4767.77115035, loss=log -   0.2s
# [CV] penalty=l1, alpha=4767.77115035, loss=log .......................
# [CV] .............. penalty=l1, alpha=4767.77115035, loss=log -   0.2s
# [CV] penalty=l1, alpha=4767.77115035, loss=log .......................
# [CV] .............. penalty=l1, alpha=4767.77115035, loss=log -   0.2s
# [CV] penalty=l1, alpha=4767.77115035, loss=log .......................
# [CV] .............. penalty=l1, alpha=4767.77115035, loss=log -   0.2s
# [CV] penalty=l1, alpha=4503.18485073, loss=log .......................
# [CV] .............. penalty=l1, alpha=4503.18485073, loss=log -   0.2s
# [CV] penalty=l1, alpha=4503.18485073, loss=log .......................
# [CV] .............. penalty=l1, alpha=4503.18485073, loss=log -   0.2s
# [CV] penalty=l1, alpha=4503.18485073, loss=log .......................
# [CV] .............. penalty=l1, alpha=4503.18485073, loss=log -   0.2s
# [CV] penalty=l1, alpha=4503.18485073, loss=log .......................
# [CV] .............. penalty=l1, alpha=4503.18485073, loss=log -   0.2s
# [CV] penalty=l1, alpha=4503.18485073, loss=log .......................
# [CV] .............. penalty=l1, alpha=4503.18485073, loss=log -   0.2s
# [CV] penalty=l1, alpha=15339.7439753, loss=log .......................
# [CV] .............. penalty=l1, alpha=15339.7439753, loss=log -   0.2s
# [CV] penalty=l1, alpha=15339.7439753, loss=log .......................
# [CV] .............. penalty=l1, alpha=15339.7439753, loss=log -   0.2s
# [CV] penalty=l1, alpha=15339.7439753, loss=log .......................
# [CV] .............. penalty=l1, alpha=15339.7439753, loss=log -   0.2s
# [CV] penalty=l1, alpha=15339.7439753, loss=log .......................
# [CV] .............. penalty=l1, alpha=15339.7439753, loss=log -   0.2s
# [CV] penalty=l1, alpha=15339.7439753, loss=log .......................
# [CV] .............. penalty=l1, alpha=15339.7439753, loss=log -   0.2s
# [CV] penalty=l1, alpha=4116.71569852, loss=log .......................
# [CV] .............. penalty=l1, alpha=4116.71569852, loss=log -   0.2s
# [CV] penalty=l1, alpha=4116.71569852, loss=log .......................
# [CV] .............. penalty=l1, alpha=4116.71569852, loss=log -   0.2s
# [CV] penalty=l1, alpha=4116.71569852, loss=log .......................
# [CV] .............. penalty=l1, alpha=4116.71569852, loss=log -   0.2s
# [CV] penalty=l1, alpha=4116.71569852, loss=log .......................
# [CV] .............. penalty=l1, alpha=4116.71569852, loss=log -   0.2s
# [CV] penalty=l1, alpha=4116.71569852, loss=log .......................
# [CV] .............. penalty=l1, alpha=4116.71569852, loss=log -   0.2s
# [CV] penalty=l2, alpha=7581.05400096, loss=log .......................
# [CV] .............. penalty=l2, alpha=7581.05400096, loss=log -   0.1s
# [CV] penalty=l2, alpha=7581.05400096, loss=log .......................
# [CV] .............. penalty=l2, alpha=7581.05400096, loss=log -   0.1s
# [CV] penalty=l2, alpha=7581.05400096, loss=log .......................
# [CV] .............. penalty=l2, alpha=7581.05400096, loss=log -   0.1s
# [CV] penalty=l2, alpha=7581.05400096, loss=log .......................
# [CV] .............. penalty=l2, alpha=7581.05400096, loss=log -   0.1s
# [CV] penalty=l2, alpha=7581.05400096, loss=log .......................
# [CV] .............. penalty=l2, alpha=7581.05400096, loss=log -   0.1s
# [CV] penalty=l2, alpha=12951.3464204, loss=log .......................
# [CV] .............. penalty=l2, alpha=12951.3464204, loss=log -   0.1s
# [CV] penalty=l2, alpha=12951.3464204, loss=log .......................
# [CV] .............. penalty=l2, alpha=12951.3464204, loss=log -   0.1s
# [CV] penalty=l2, alpha=12951.3464204, loss=log .......................
# [CV] .............. penalty=l2, alpha=12951.3464204, loss=log -   0.1s
# [CV] penalty=l2, alpha=12951.3464204, loss=log .......................
# [CV] .............. penalty=l2, alpha=12951.3464204, loss=log -   0.1s
# [CV] penalty=l2, alpha=12951.3464204, loss=log .......................
# [CV] .............. penalty=l2, alpha=12951.3464204, loss=log -   0.1s
# [CV] penalty=l1, alpha=18476.9781766, loss=log .......................
# [CV] .............. penalty=l1, alpha=18476.9781766, loss=log -   0.2s
# [CV] penalty=l1, alpha=18476.9781766, loss=log .......................
# [CV] .............. penalty=l1, alpha=18476.9781766, loss=log -   0.2s
# [CV] penalty=l1, alpha=18476.9781766, loss=log .......................
# [CV] .............. penalty=l1, alpha=18476.9781766, loss=log -   0.2s
# [CV] penalty=l1, alpha=18476.9781766, loss=log .......................
# [CV] .............. penalty=l1, alpha=18476.9781766, loss=log -   0.2s
# [CV] penalty=l1, alpha=18476.9781766, loss=log .......................
# [CV] .............. penalty=l1, alpha=18476.9781766, loss=log -   0.2s
# [CV] penalty=l2, alpha=11571.0992709, loss=log .......................
# [CV] .............. penalty=l2, alpha=11571.0992709, loss=log -   0.1s
# [CV] penalty=l2, alpha=11571.0992709, loss=log .......................
# [CV] .............. penalty=l2, alpha=11571.0992709, loss=log -   0.1s
# [CV] penalty=l2, alpha=11571.0992709, loss=log .......................
# [CV] .............. penalty=l2, alpha=11571.0992709, loss=log -   0.1s
# [CV] penalty=l2, alpha=11571.0992709, loss=log .......................
# [CV] .............. penalty=l2, alpha=11571.0992709, loss=log -   0.1s
# [CV] penalty=l2, alpha=11571.0992709, loss=log .......................
# [CV] .............. penalty=l2, alpha=11571.0992709, loss=log -   0.1s
# [CV] penalty=l1, alpha=5977.9565409, loss=log ........................
# [CV] ............... penalty=l1, alpha=5977.9565409, loss=log -   0.2s
# [CV] penalty=l1, alpha=5977.9565409, loss=log ........................
# [CV] ............... penalty=l1, alpha=5977.9565409, loss=log -   0.2s
# [CV] penalty=l1, alpha=5977.9565409, loss=log ........................
# [CV] ............... penalty=l1, alpha=5977.9565409, loss=log -   0.2s
# [CV] penalty=l1, alpha=5977.9565409, loss=log ........................
# [CV] ............... penalty=l1, alpha=5977.9565409, loss=log -   0.2s
# [CV] penalty=l1, alpha=5977.9565409, loss=log ........................
# [CV] ............... penalty=l1, alpha=5977.9565409, loss=log -   0.2s
# [CV] penalty=l2, alpha=16813.3992308, loss=log .......................
# [CV] .............. penalty=l2, alpha=16813.3992308, loss=log -   0.1s
# [CV] penalty=l2, alpha=16813.3992308, loss=log .......................
# [CV] .............. penalty=l2, alpha=16813.3992308, loss=log -   0.1s
# [CV] penalty=l2, alpha=16813.3992308, loss=log .......................
# [CV] .............. penalty=l2, alpha=16813.3992308, loss=log -   0.1s
# [CV] penalty=l2, alpha=16813.3992308, loss=log .......................
# [CV] .............. penalty=l2, alpha=16813.3992308, loss=log -   0.1s
# [CV] penalty=l2, alpha=16813.3992308, loss=log .......................
# [CV] .............. penalty=l2, alpha=16813.3992308, loss=log -   0.1s
# [CV] penalty=l1, alpha=17652.2685173, loss=log .......................
# [CV] .............. penalty=l1, alpha=17652.2685173, loss=log -   0.2s
# [CV] penalty=l1, alpha=17652.2685173, loss=log .......................
# [CV] .............. penalty=l1, alpha=17652.2685173, loss=log -   0.2s
# [CV] penalty=l1, alpha=17652.2685173, loss=log .......................
# [CV] .............. penalty=l1, alpha=17652.2685173, loss=log -   0.2s
# [CV] penalty=l1, alpha=17652.2685173, loss=log .......................
# [CV] .............. penalty=l1, alpha=17652.2685173, loss=log -   0.2s
# [CV] penalty=l1, alpha=17652.2685173, loss=log .......................
# [CV] .............. penalty=l1, alpha=17652.2685173, loss=log -   0.2s
# [CV] penalty=l1, alpha=18010.9826335, loss=log .......................
# [CV] .............. penalty=l1, alpha=18010.9826335, loss=log -   0.2s
# [CV] penalty=l1, alpha=18010.9826335, loss=log .......................
# [CV] .............. penalty=l1, alpha=18010.9826335, loss=log -   0.2s
# [CV] penalty=l1, alpha=18010.9826335, loss=log .......................
# [CV] .............. penalty=l1, alpha=18010.9826335, loss=log -   0.2s
# [CV] penalty=l1, alpha=18010.9826335, loss=log .......................
# [CV] .............. penalty=l1, alpha=18010.9826335, loss=log -   0.2s
# [CV] penalty=l1, alpha=18010.9826335, loss=log .......................
# [CV] .............. penalty=l1, alpha=18010.9826335, loss=log -   0.2s
# [CV] penalty=l1, alpha=7677.75778792, loss=log .......................
# [CV] .............. penalty=l1, alpha=7677.75778792, loss=log -   0.2s
# [CV] penalty=l1, alpha=7677.75778792, loss=log .......................
# [CV] .............. penalty=l1, alpha=7677.75778792, loss=log -   0.2s
# [CV] penalty=l1, alpha=7677.75778792, loss=log .......................
# [CV] .............. penalty=l1, alpha=7677.75778792, loss=log -   0.2s
# [CV] penalty=l1, alpha=7677.75778792, loss=log .......................
# [CV] .............. penalty=l1, alpha=7677.75778792, loss=log -   0.2s
# [CV] penalty=l1, alpha=7677.75778792, loss=log .......................
# [CV] .............. penalty=l1, alpha=7677.75778792, loss=log -   0.2s
# [CV] penalty=l1, alpha=6932.02894949, loss=log .......................
# [CV] .............. penalty=l1, alpha=6932.02894949, loss=log -   0.2s
# [CV] penalty=l1, alpha=6932.02894949, loss=log .......................
# [CV] .............. penalty=l1, alpha=6932.02894949, loss=log -   0.2s
# [CV] penalty=l1, alpha=6932.02894949, loss=log .......................
# [CV] .............. penalty=l1, alpha=6932.02894949, loss=log -   0.2s
# [CV] penalty=l1, alpha=6932.02894949, loss=log .......................
# [CV] .............. penalty=l1, alpha=6932.02894949, loss=log -   0.2s
# [CV] penalty=l1, alpha=6932.02894949, loss=log .......................
# [CV] .............. penalty=l1, alpha=6932.02894949, loss=log -   0.2s
# [CV] penalty=l2, alpha=14841.0726826, loss=log .......................
# [CV] .............. penalty=l2, alpha=14841.0726826, loss=log -   0.1s
# [CV] penalty=l2, alpha=14841.0726826, loss=log .......................
# [CV] .............. penalty=l2, alpha=14841.0726826, loss=log -   0.1s
# [CV] penalty=l2, alpha=14841.0726826, loss=log .......................
# [CV] .............. penalty=l2, alpha=14841.0726826, loss=log -   0.1s
# [CV] penalty=l2, alpha=14841.0726826, loss=log .......................
# [CV] .............. penalty=l2, alpha=14841.0726826, loss=log -   0.1s
# [CV] penalty=l2, alpha=14841.0726826, loss=log .......................
# [CV] .............. penalty=l2, alpha=14841.0726826, loss=log -   0.1s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:  1.5min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False),
#           fit_params={}, iid=True, n_iter=100, n_jobs=1,
#           param_distributions={'penalty': ['l1', 'l2'], 'loss': ['log'], 'alpha': <scipy.stats._distn_infrastructure.rv_frozen object at 0x11a7460d0>},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           scoring=None, verbose=2)

# %%
print sgd_cls_gs.best_params_
print sgd_cls_gs.best_score_
sgd_cls = sgd_cls_gs.best_estimator_
# Out:
# {'penalty': 'l1', 'alpha': 4195.3365012364075, 'loss': 'log'}
# 0.840533587928

# %%
sgd_cls_gs_params = sgd_cls_gs.get_params()
sgd_cls_gs_alphas = np.linspace(1., np.max(sgd_cls_gs.best_params_['alpha']), 100)

# %% [markdown]
# ---
#
# ### Visualize/examine the results of the classifier
#
# Just like above.

# %%
lcls_coefs = lasso_coefs(Xn, y, sgd_cls_gs_alphas)

# %%
# Plot the coefficients across alpha values:
fig, ax = plt.subplots(figsize=(11,7))

ax.plot(sgd_cls_gs_alphas, lcls_coefs, lw=1.5)

ax.axvline(sgd_cls_gs.best_params_['alpha'], lw=1.0, ls='dashed', label='best alpha')

ax.set_title('Classifier RandomizedSearchCV coef values across alphas')
ax.set_xlabel('alpha')
ax.set_ylabel('coef value')

plt.legend(loc='upper right')

plt.show()
