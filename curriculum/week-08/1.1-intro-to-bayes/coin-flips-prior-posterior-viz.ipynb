# %% [markdown]
# # Visualization of coin flip posterior update

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.style.use('fivethirtyeight')

from ipywidgets import *
from IPython.display import display

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import imp
plotter = imp.load_source('plotter', '/Users/kiefer/github-repos/DSI-SF-2/utils/plotting/prior_posterior_plotter.py')
from plotter import BetaPriorPosterior

plotter = BetaPriorPosterior()
plotter.bayes_interact()
